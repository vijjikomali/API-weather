# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import os
from pprint import pprint
# Import API key
# import api_keys
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = os.path.join("output_data","cities.csv")

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
api_key
# Out:
# '060a1f5e08d612b9846c0c45534ae537'

# %%
citipy
# Out:
# <module 'citipy.citipy' from 'C:\\Users\\Vijayalaskmi\\Anaconda3\\lib\\site-packages\\citipy\\citipy.py'>

# %%
coordinates = [(200, 200), (23, 200), (42, 100)]

# %% [markdown]
# ## Generate Cities List
# Your objective is to build a series of scatter plots to showcase the following relationships:
#
#
# 1. Temperature (F) vs. Latitude
#
# 2. Humidity (%) vs. Latitude
#
# 3. Cloudiness (%) vs. Latitude
#
# 4. Wind Speed (mph) vs. Latitude

# %%
namelist = []
cityidlist = []
latitudelist = []
temperaturelist = []
humiditylist = []
cloudinesslist = []
windspeedlist = []
countrylist = []

# %%
# List for holding lat_lngs and cities
# n = 500
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 585

# %%
for each in enumerate(cities):
    print(each)
# Out:
# (0, 'rikitea')
# (1, 'saint-philippe')
# (2, 'narsaq')
# (3, 'taolanaro')
# (4, 'hobart')
# (5, 'vao')
# (6, 'ushuaia')
# (7, 'torbay')
# (8, 'berlevag')
# (9, 'port alfred')
# (10, 'necochea')
# (11, 'kapaa')
# (12, 'bengkulu')
# (13, 'arraial do cabo')
# (14, 'hilo')
# (15, 'bluff')
# (16, 'vaini')
# (17, 'toliary')
# (18, 'cabo san lucas')
# (19, 'adrar')
# (20, 'umm durman')
# (21, 'pangnirtung')
# (22, 'airai')
# (23, 'punta arenas')
# (24, 'albany')
# (25, 'thompson')
# (26, 'batticaloa')
# (27, 'nanortalik')
# (28, 'jamestown')
# (29, 'chuy')
# (30, 'barbar')
# (31, 'coquimbo')
# (32, 'castro')
# (33, 'dalvik')
# (34, 'port elizabeth')
# (35, 'east london')
# (36, 'atuona')
# (37, 'nizhneyansk')
# (38, 'crab hill')
# (39, 'bambous virieux')
# (40, 'qaanaaq')
# (41, 'mareeba')
# (42, 'bathsheba')
# (43, 'batagay-alyta')
# (44, 'carnarvon')
# (45, 'khatanga')
# (46, 'praia da vitoria')
# (47, 'te anau')
# (48, 'isangel')
# (49, 'sampit')
# (50, 'busselton')
# (51, 'dikson')
# (52, 'talnakh')
# (53, 'pangai')
# (54, 'jaisalmer')
# (55, 'buala')
# (56, 'saint-augustin')
# (57, 'skibbereen')
# (58, 'tongzi')
# (59, 'rocha')
# (60, 'chapada dos guimaraes')
# (61, 'pisco')
# (62, 'mackay')
# (63, 'oskemen')
# (64, 'cidreira')
# (65, 'hermanus')
# (66, 'ancud')
# (67, 'dzhusaly')
# (68, 'deputatskiy')
# (69, 'yeppoon')
# (70, 'ribeira grande')
# (71, 'cockburn town')
# (72, 'bestobe')
# (73, 'meyungs')
# (74, 'egvekinot')
# (75, 'chokurdakh')
# (76, 'mataura')
# (77, 'qaqortoq')
# (78, 'sinegorye')
# (79, 'hasaki')
# (80, 'new norfolk')
# (81, 'longyearbyen')
# (82, 'banjar')
# (83, 'babanusah')
# (84, 'maniitsoq')
# (85, 'palabuhanratu')
# (86, 'verkhnevilyuysk')
# (87, 'tazovskiy')
# (88, 'tasiilaq')
# (89, 'nikolskoye')
# (90, 'dingle')
# (91, 'esperance')
# (92, 'fortuna')
# (93, 'almaznyy')
# (94, 'erenhot')
# (95, 'college')
# (96, 'ozernovskiy')
# (97, 'ilulissat')
# (98, 'bintulu')
# (99, 'san patricio')
# (100, 'erzin')
# (101, 'rawson')
# (102, 'araouane')
# (103, 'grindavik')
# (104, 'puerto ayora')
# (105, 'tongchuan')
# (106, 'faanui')
# (107, 'sentyabrskiy')
# (108, 'barrow')
# (109, 'lagoa')
# (110, 'halifax')
# (111, 'mar del plata')
# (112, 'znamenskoye')
# (113, 'sitka')
# (114, 'tuktoyaktuk')
# (115, 'sioux lookout')
# (116, 'kendari')
# (117, 'ostrovnoy')
# (118, 'abha')
# (119, 'ust-nera')
# (120, 'nome')
# (121, 'yellowknife')
# (122, 'ozgon')
# (123, 'souillac')
# (124, 'cherskiy')
# (125, 'nikolayevsk-na-amure')
# (126, 'wilmington')
# (127, 'butaritari')
# (128, 'baruun-urt')
# (129, 'tateyama')
# (130, 'vaitupu')
# (131, 'qasigiannguit')
# (132, 'hithadhoo')
# (133, 'vanderhoof')
# (134, 'inderborskiy')
# (135, 'haibowan')
# (136, 'paka')
# (137, 'chepareria')
# (138, 'utiroa')
# (139, 'evensk')
# (140, 'illoqqortoormiut')
# (141, 'port-gentil')
# (142, 'cape town')
# (143, 'husavik')
# (144, 'attawapiskat')
# (145, 'taubate')
# (146, 'bima')
# (147, 'roald')
# (148, 'namatanai')
# (149, 'tiksi')
# (150, 'celestun')
# (151, 'upernavik')
# (152, 'viedma')
# (153, 'umba')
# (154, 'barentsburg')
# (155, 'margate')
# (156, 'alaminos')
# (157, 'kodiak')
# (158, 'tonota')
# (159, 'fort nelson')
# (160, 'tekeli')
# (161, 'mahebourg')
# (162, 'hobyo')
# (163, 'bardiyah')
# (164, 'palmer')
# (165, 'puerto escondido')
# (166, 'lapua')
# (167, 'shimoda')
# (168, 'kruisfontein')
# (169, 'alofi')
# (170, 'marcona')
# (171, 'fairbanks')
# (172, 'dolbeau')
# (173, 'ramgarh')
# (174, 'bredasdorp')
# (175, 'amderma')
# (176, 'kangaatsiaq')
# (177, 'pechenga')
# (178, 'ponta do sol')
# (179, 'tsihombe')
# (180, 'emborion')
# (181, 'bulgan')
# (182, 'mantua')
# (183, 'kawalu')
# (184, 'taguatinga')
# (185, 'tabukiniberu')
# (186, 'comodoro rivadavia')
# (187, 'aswan')
# (188, 'cizre')
# (189, 'srednekolymsk')
# (190, 'chipinge')
# (191, 'amapa')
# (192, 'viligili')
# (193, 'kloulklubed')
# (194, 'lannion')
# (195, 'richards bay')
# (196, 'belushya guba')
# (197, 'guanica')
# (198, 'berbera')
# (199, 'angoche')
# (200, 'navur')
# (201, 'tuatapere')
# (202, 'beringovskiy')
# (203, 'plouzane')
# (204, 'mazagao')
# (205, 'nyurba')
# (206, 'north platte')
# (207, 'galesong')
# (208, 'langsa')
# (209, 'farah')
# (210, 'mys shmidta')
# (211, 'russell')
# (212, 'hambantota')
# (213, 'ustrzyki dolne')
# (214, 'iqaluit')
# (215, 'nioaque')
# (216, 'brigantine')
# (217, 'hamilton')
# (218, 'koslan')
# (219, 'pevek')
# (220, 'touros')
# (221, 'alta floresta')
# (222, 'saleaula')
# (223, 'labuhan')
# (224, 'shingu')
# (225, 'nanyang')
# (226, 'aksarka')
# (227, 'maroantsetra')
# (228, 'hervey bay')
# (229, 'avarua')
# (230, 'marfino')
# (231, 'lompoc')
# (232, 'kenai')
# (233, 'grimma')
# (234, 'mindupok')
# (235, 'marsh harbour')
# (236, 'totskoye')
# (237, 'euclid')
# (238, 'harper')
# (239, 'kavieng')
# (240, 'labuan')
# (241, 'asau')
# (242, 'pirovskoye')
# (243, 'provideniya')
# (244, 'victoria')
# (245, 'lolua')
# (246, 'tessalit')
# (247, 'port hardy')
# (248, 'hofn')
# (249, 'qiongshan')
# (250, 'sorvag')
# (251, 'port shepstone')
# (252, 'saint-francois')
# (253, 'axim')
# (254, 'rio grande')
# (255, 'los llanos de aridane')
# (256, 'areosa')
# (257, 'balkanabat')
# (258, 'cabedelo')
# (259, 'pandan')
# (260, 'bethel')
# (261, 'goma')
# (262, 'osmanabad')
# (263, 'aparecida do taboado')
# (264, 'klaksvik')
# (265, 'umzimvubu')
# (266, 'nioro')
# (267, 'ginda')
# (268, 'yangambi')
# (269, 'akrata')
# (270, 'krasnokamensk')
# (271, 'layou')
# (272, 'yulara')
# (273, 'villa bruzual')
# (274, 'stornoway')
# (275, 'yumen')
# (276, 'quelimane')
# (277, 'makubetsu')
# (278, 'riyadh')
# (279, 'lorengau')
# (280, 'vostok')
# (281, 'ballina')
# (282, 'lethem')
# (283, 'kansanshi')
# (284, 'georgetown')
# (285, 'grand river south east')
# (286, 'achisay')
# (287, 'mawlaik')
# (288, 'vila velha')
# (289, 'guerrero negro')
# (290, 'grenville')
# (291, 'caconda')
# (292, 'andenes')
# (293, 'kachikau')
# (294, 'ingham')
# (295, 'dalbandin')
# (296, 'killybegs')
# (297, 'nanakuli')
# (298, 'severo-kurilsk')
# (299, 'kysyl-syr')
# (300, 'grand-lahou')
# (301, 'saint george')
# (302, 'meulaboh')
# (303, 'coro')
# (304, 'ales')
# (305, 'salinopolis')
# (306, 'masuguru')
# (307, 'ewa beach')
# (308, 'la rioja')
# (309, 'kuva')
# (310, 'kieta')
# (311, 'yichang')
# (312, 'brae')
# (313, 'nouadhibou')
# (314, 'makakilo city')
# (315, 'chapleau')
# (316, 'cheuskiny')
# (317, 'yuzhno-yeniseyskiy')
# (318, 'balkhash')
# (319, 'requena')
# (320, 'mobaye')
# (321, 'dudinka')
# (322, 'kamenka')
# (323, 'maarianhamina')
# (324, 'tuy hoa')
# (325, 'guasdualito')
# (326, 'marawi')
# (327, 'daru')
# (328, 'villa bisono')
# (329, 'chara')
# (330, 'dhupgari')
# (331, 'uyuni')
# (332, 'inverell')
# (333, 'hualmay')
# (334, 'lavrentiya')
# (335, 'nemuro')
# (336, 'katherine')
# (337, 'solnechnyy')
# (338, 'taoudenni')
# (339, 'sambava')
# (340, 'lata')
# (341, 'vad')
# (342, 'eyl')
# (343, 'maracai')
# (344, 'katsuura')
# (345, 'teplodar')
# (346, 'westport')
# (347, 'tabiauea')
# (348, 'wasilla')
# (349, 'nelson bay')
# (350, 'bhayavadar')
# (351, 'gazanjyk')
# (352, 'kronach')
# (353, 'abu samrah')
# (354, 'isla vista')
# (355, 'juneau')
# (356, 'tumannyy')
# (357, 'puri')
# (358, 'big rapids')
# (359, 'sao filipe')
# (360, 'karauzyak')
# (361, 'phangnga')
# (362, 'shakhtinsk')
# (363, 'moose factory')
# (364, 'saskylakh')
# (365, 'tucuman')
# (366, 'tautira')
# (367, 'ondangwa')
# (368, 'sirfa')
# (369, 'gao')
# (370, 'torrington')
# (371, 'wexford')
# (372, 'carnot')
# (373, 'urengoy')
# (374, 'ystad')
# (375, 'tomatlan')
# (376, 'norman wells')
# (377, 'nueva loja')
# (378, 'antofagasta')
# (379, 'kaeo')
# (380, 'makhachkala')
# (381, 'wawa')
# (382, 'sokoni')
# (383, 'kumukh')
# (384, 'sorland')
# (385, 'mercedes')
# (386, 'geraldton')
# (387, 'cheney')
# (388, 'ratnagiri')
# (389, 'mahanje')
# (390, 'belgaum')
# (391, 'zhigansk')
# (392, 'salalah')
# (393, 'karaul')
# (394, 'vlore')
# (395, 'gebze')
# (396, 'sarakhs')
# (397, 'luderitz')
# (398, 'flinders')
# (399, 'maldonado')
# (400, 'lebu')
# (401, 'blackwater')
# (402, 'kropotkin')
# (403, 'tabou')
# (404, 'areia')
# (405, 'magistralnyy')
# (406, 'teneguiban')
# (407, 'tubmanburg')
# (408, 'yuxia')
# (409, 'vicuna')
# (410, 'khani')
# (411, 'praia')
# (412, 'corinto')
# (413, 'kununurra')
# (414, 'dombarovskiy')
# (415, 'sawtell')
# (416, 'vardo')
# (417, 'linxia')
# (418, 'atambua')
# (419, 'naze')
# (420, 'baykit')
# (421, 'penalva')
# (422, 'gardenstown')
# (423, 'havelock')
# (424, 'tilichiki')
# (425, 'moscow')
# (426, 'hobbs')
# (427, 'hvolsvollur')
# (428, 'leningradskiy')
# (429, 'bambanglipuro')
# (430, 'orodara')
# (431, 'fomboni')
# (432, 'olinda')
# (433, 'aklavik')
# (434, 'katihar')
# (435, 'oranjemund')
# (436, 'vaitape')
# (437, 'sinnamary')
# (438, 'auki')
# (439, 'atar')
# (440, 'haines junction')
# (441, 'katha')
# (442, 'muroto')
# (443, 'acajutla')
# (444, 'gizo')
# (445, 'cayenne')
# (446, 'filingue')
# (447, 'portland')
# (448, 'yerbogachen')
# (449, 'abancay')
# (450, 'goderich')
# (451, 'kodino')
# (452, 'aasiaat')
# (453, 'aligudarz')
# (454, 'hue')
# (455, 'sao felix do xingu')
# (456, 'takoradi')
# (457, 'sheridan')
# (458, 'buchanan')
# (459, 'binzhou')
# (460, 'san jeronimo')
# (461, 'malinovoye ozero')
# (462, 'khrystynivka')
# (463, 'banda aceh')
# (464, 'mattoon')
# (465, 'khavarion')
# (466, 'fukue')
# (467, 'saint-joseph')
# (468, 'andros town')
# (469, 'arman')
# (470, 'lazarev')
# (471, 'pingdingshan')
# (472, 'bougouni')
# (473, 'mount darwin')
# (474, 'whitehorse')
# (475, 'haapiti')
# (476, 'coahuayana')
# (477, 'sept-iles')
# (478, 'ust-maya')
# (479, 'scarborough')
# (480, 'porto torres')
# (481, 'pingliang')
# (482, 'kudahuvadhoo')
# (483, 'hit')
# (484, 'waingapu')
# (485, 'khanpur')
# (486, 'roanoke rapids')
# (487, 'muravlenko')
# (488, 'vila franca do campo')
# (489, 'doctor pedro p. pena')
# (490, 'sapele')
# (491, 'esil')
# (492, 'puerto madryn')
# (493, 'barentu')
# (494, 'kushmurun')
# (495, 'puerto lempira')
# (496, 'shevchenkove')
# (497, 'hunza')
# (498, 'petauke')
# (499, 'udachnyy')
# (500, 'kostyantynivka')
# (501, 'paralimni')
# (502, 'togur')
# (503, 'tahta')
# (504, 'vanimo')
# (505, 'phuket')
# (506, 'tongling')
# (507, 'ko samui')
# (508, 'murmansk')
# (509, 'chapais')
# (510, 'derzhavinsk')
# (511, 'mineiros')
# (512, 'gumdag')
# (513, 'de-kastri')
# (514, 'thai binh')
# (515, 'maracaibo')
# (516, 'kisiwani')
# (517, 'alotau')
# (518, 'liverpool')
# (519, 'bahia blanca')
# (520, 'mount barker')
# (521, 'olafsvik')
# (522, 'pasighat')
# (523, 'wanganui')
# (524, 'chebsara')
# (525, 'the valley')
# (526, 'pioner')
# (527, 'henties bay')
# (528, 'dunedin')
# (529, 'bur gabo')
# (530, 'gongzhuling')
# (531, 'manali')
# (532, 'inhambane')
# (533, 'petropavlovsk-kamchatskiy')
# (534, 'dandong')
# (535, 'jaumave')
# (536, 'bilma')
# (537, 'namwala')
# (538, 'alenquer')
# (539, 'pineville')
# (540, 'kavaratti')
# (541, 'cartersville')
# (542, 'pyinmana')
# (543, 'fonte boa')
# (544, 'marsabit')
# (545, 'ambovombe')
# (546, 'esmeralda')
# (547, 'port blair')
# (548, 'venado tuerto')
# (549, 'san francisco menendez')
# (550, 'batsfjord')
# (551, 'seddon')
# (552, 'okato')
# (553, 'benghazi')
# (554, 'ossora')
# (555, 'matina')
# (556, 'avera')
# (557, 'usinsk')
# (558, 'pottsville')
# (559, 'joshimath')
# (560, 'itarema')
# (561, 'el campo')
# (562, 'kayerkan')
# (563, 'jever')
# (564, 'saldanha')
# (565, 'nanchang')
# (566, 'marrakesh')
# (567, 'poum')
# (568, 'nyimba')
# (569, 'akyab')
# (570, 'mandera')
# (571, 'kazalinsk')
# (572, 'potgietersrus')
# (573, 'hay river')
# (574, 'troitskoye')
# (575, 'suluq')
# (576, 'negombo')
# (577, 'karpogory')
# (578, 'kasongo-lunda')
# (579, 'chase')
# (580, 'cabalaoangan')
# (581, 'turukhansk')
# (582, 'santa vitoria')
# (583, 'kaitangata')
# (584, 'sanandaj')

# %% [markdown]
# cities

# %%
# Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
query_url = f"{url}appid={api_key}&units={units}&q="

# %%
query_url
units
# Out:
# 'metric'

# %%
lat = []
temp = []
print(f"Beginning Data Retrieval  ")
print("----------------------------")
# Loop through the list of cities and perform a request for data on each
#for city in cities:
for index, each in enumerate(cities):

    response = requests.get(query_url + each).json()
    try:
        lat.append(response['coord']['lat'])
        temp.append(response['main']['temp'])
        print(f"Processing Record {index} of Set 1 | {each}")
    
    
    
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")

# print(f"The latitude information received is: {lat}")
# print(f"The temperature information received is: {temp}")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record 0 of Set 1 | rikitea
# Processing Record 1 of Set 1 | saint-philippe
# Processing Record 2 of Set 1 | narsaq
# Missing field/result... skipping.
# Processing Record 4 of Set 1 | hobart
# Processing Record 5 of Set 1 | vao
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | torbay
# Processing Record 8 of Set 1 | berlevag
# Processing Record 9 of Set 1 | port alfred
# Processing Record 10 of Set 1 | necochea
# Processing Record 11 of Set 1 | kapaa
# Missing field/result... skipping.
# Processing Record 13 of Set 1 | arraial do cabo
# Processing Record 14 of Set 1 | hilo
# Processing Record 15 of Set 1 | bluff
# Processing Record 16 of Set 1 | vaini
# Missing field/result... skipping.
# Processing Record 18 of Set 1 | cabo san lucas
# Processing Record 19 of Set 1 | adrar
# Missing field/result... skipping.
# Processing Record 21 of Set 1 | pangnirtung
# Processing Record 22 of Set 1 | airai
# Processing Record 23 of Set 1 | punta arenas
# Processing Record 24 of Set 1 | albany
# Processing Record 25 of Set 1 | thompson
# Processing Record 26 of Set 1 | batticaloa
# Processing Record 27 of Set 1 | nanortalik
# Processing Record 28 of Set 1 | jamestown
# Processing Record 29 of Set 1 | chuy
# Missing field/result... skipping.
# Processing Record 31 of Set 1 | coquimbo
# Processing Record 32 of Set 1 | castro
# Processing Record 33 of Set 1 | dalvik
# Processing Record 34 of Set 1 | port elizabeth
# Processing Record 35 of Set 1 | east london
# Processing Record 36 of Set 1 | atuona
# Missing field/result... skipping.
# Missing field/result... skipping.
# Processing Record 39 of Set 1 | bambous virieux
# Processing Record 40 of Set 1 | qaanaaq
# Processing Record 41 of Set 1 | mareeba
# Processing Record 42 of Set 1 | bathsheba
# Processing Record 43 of Set 1 | batagay-alyta
# Processing Record 44 of Set 1 | carnarvon
# Processing Record 45 of Set 1 | khatanga
# Processing Record 46 of Set 1 | praia da vitoria
# Processing Record 47 of Set 1 | te anau
# Processing Record 48 of Set 1 | isangel
# Processing Record 49 of Set 1 | sampit
# Processing Record 50 of Set 1 | busselton
# Processing Record 51 of Set 1 | dikson
# Processing Record 52 of Set 1 | talnakh
# Processing Record 53 of Set 1 | pangai
# Processing Record 54 of Set 1 | jaisalmer
# Processing Record 55 of Set 1 | buala
# Processing Record 56 of Set 1 | saint-augustin
# Processing Record 57 of Set 1 | skibbereen
# Processing Record 58 of Set 1 | tongzi
# Processing Record 59 of Set 1 | rocha
# Processing Record 60 of Set 1 | chapada dos guimaraes
# Processing Record 61 of Set 1 | pisco
# Processing Record 62 of Set 1 | mackay
# Processing Record 63 of Set 1 | oskemen
# Processing Record 64 of Set 1 | cidreira
# Processing Record 65 of Set 1 | hermanus
# Processing Record 66 of Set 1 | ancud
# Missing field/result... skipping.
# Processing Record 68 of Set 1 | deputatskiy
# Processing Record 69 of Set 1 | yeppoon
# Processing Record 70 of Set 1 | ribeira grande
# Processing Record 71 of Set 1 | cockburn town
# Processing Record 72 of Set 1 | bestobe
# Missing field/result... skipping.
# Processing Record 74 of Set 1 | egvekinot
# Processing Record 75 of Set 1 | chokurdakh
# Processing Record 76 of Set 1 | mataura
# Processing Record 77 of Set 1 | qaqortoq
# Processing Record 78 of Set 1 | sinegorye
# Processing Record 79 of Set 1 | hasaki
# Processing Record 80 of Set 1 | new norfolk
# Processing Record 81 of Set 1 | longyearbyen
# Processing Record 82 of Set 1 | banjar
# Missing field/result... skipping.
# Processing Record 84 of Set 1 | maniitsoq
# Missing field/result... skipping.
# Processing Record 86 of Set 1 | verkhnevilyuysk
# Processing Record 87 of Set 1 | tazovskiy
# Processing Record 88 of Set 1 | tasiilaq
# Processing Record 89 of Set 1 | nikolskoye
# Processing Record 90 of Set 1 | dingle
# Processing Record 91 of Set 1 | esperance
# Processing Record 92 of Set 1 | fortuna
# Processing Record 93 of Set 1 | almaznyy
# Processing Record 94 of Set 1 | erenhot
# Processing Record 95 of Set 1 | college
# Processing Record 96 of Set 1 | ozernovskiy
# Processing Record 97 of Set 1 | ilulissat
# Processing Record 98 of Set 1 | bintulu
# Processing Record 99 of Set 1 | san patricio
# Processing Record 100 of Set 1 | erzin
# Processing Record 101 of Set 1 | rawson
# Processing Record 102 of Set 1 | araouane
# Processing Record 103 of Set 1 | grindavik
# Processing Record 104 of Set 1 | puerto ayora
# Processing Record 105 of Set 1 | tongchuan
# Processing Record 106 of Set 1 | faanui
# Missing field/result... skipping.
# Processing Record 108 of Set 1 | barrow
# Processing Record 109 of Set 1 | lagoa
# Processing Record 110 of Set 1 | halifax
# Processing Record 111 of Set 1 | mar del plata
# Processing Record 112 of Set 1 | znamenskoye
# Processing Record 113 of Set 1 | sitka
# Processing Record 114 of Set 1 | tuktoyaktuk
# Processing Record 115 of Set 1 | sioux lookout
# Processing Record 116 of Set 1 | kendari
# Processing Record 117 of Set 1 | ostrovnoy
# Processing Record 118 of Set 1 | abha
# Processing Record 119 of Set 1 | ust-nera
# Processing Record 120 of Set 1 | nome
# Processing Record 121 of Set 1 | yellowknife
# Missing field/result... skipping.
# Processing Record 123 of Set 1 | souillac
# Processing Record 124 of Set 1 | cherskiy
# Processing Record 125 of Set 1 | nikolayevsk-na-amure
# Processing Record 126 of Set 1 | wilmington
# Processing Record 127 of Set 1 | butaritari
# Processing Record 128 of Set 1 | baruun-urt
# Processing Record 129 of Set 1 | tateyama
# Missing field/result... skipping.
# Processing Record 131 of Set 1 | qasigiannguit
# Processing Record 132 of Set 1 | hithadhoo
# Processing Record 133 of Set 1 | vanderhoof
# Missing field/result... skipping.
# Missing field/result... skipping.
# Processing Record 136 of Set 1 | paka
# Processing Record 137 of Set 1 | chepareria
# Missing field/result... skipping.
# Processing Record 139 of Set 1 | evensk
# Missing field/result... skipping.
# Processing Record 141 of Set 1 | port-gentil
# Processing Record 142 of Set 1 | cape town
# Processing Record 143 of Set 1 | husavik

# %%
# create a data frame from cities, lat, and temp
weather_dict = {
    "city": cities,
    "lat": lat,
    "temp": temp
}
weather_data = pd.DataFrame(weather_dict)
weather_data.head()

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# #Create Scatter Plot, label and save it to a png in the Output folder, then display the plot
# plt.scatter(latitudelist, temperaturelist, marker="o", facecolors="red", edgecolors="black", alpha=0.75)
# plt.xlabel("Latitude (Degrees)")
# plt.ylabel("Temperature (Fahrenheit)")
# plt.title("City Latitude vs Average Temperature on 4/4/2018")
# plt.savefig("Output/Latitude_vs_Temperature")
# #plt.grid()
# plt.show()

# %%
# plt.scatter(urban_data, urban_avg_fare, s=urban_dr_count*.4, c="coral", alpha=.85,edgecolor="black",linewidths=1)
# plt.scatter(suburban_data, suburban_avg_fare, s=suburban_dr_count*.9, c="lightskyblue", alpha=1,edgecolor="black",linewidths=1)
# plt.scatter(rural_data, rural_avg_fare, s=rural_dr_count, c="gold", alpha=1,edgecolor="black",linewidths=1)
# plt.title("City Latitude vs. Max Temperature(10/06/2018)")
# plt.xlabel("Latitude")
# plt.ylabel("Max Temperature(F)")
# plt.legend(('Urban','Suburban','Rural'),loc = "upper right",title = "City Type",markerscale=.4)
# plt.text(45,35,"Notes:\nCircle size correlates with driver count per City")
# plt.grid(True)

# plt.show()

# %%
# plt.scatter("s=*.2, c="blue",edgecolor="black,linewidths=1)
# plt.title("City Latitude vs. Humiditym(10/06/2018)")
# plt.xlabel("Latitude")
# plt.ylabel("Humidity(%)")
# plt.grid(True)
# plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# plt.scatter("s=*.2, c="blue",edgecolor="black,linewidths=1)
# plt.title("City Latitude vs. Cloudiness(10/06/2018)")
# plt.xlabel("latitude")
# plt.ylabel("Cloudiness(%)")
# plt.grid(True)
# plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# plt.scatter("s=*.2, c="blue",edgecolor="black,linewidths=1)
# plt.title("City Latitude vs. wind Speed(10/06/2018)")
# plt.xlabel("Latitude")
# plt.ylabel("Wind Speed(mph)")
# plt.grid(True)
# plt.show()
