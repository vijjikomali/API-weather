# %%
# WeatherPy

### Analysis
#* As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
#* There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
#* There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.


#### Note
#* Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import os
import datetime
import time
from pprint import pprint
# Import API key
# import api_keys
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = os.path.join("output_data","cities.csv")

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
api_key
# Out:
# '060a1f5e08d612b9846c0c45534ae537'

# %%
citipy
# Out:
# <module 'citipy.citipy' from 'C:\\Users\\Vijayalaskmi\\Anaconda3\\lib\\site-packages\\citipy\\citipy.py'>

# %%
coordinates = [(200, 200), (23, 200), (42, 100)]

# %% [markdown]
# ## Generate Cities List
# Your objective is to build a series of scatter plots to showcase the following relationships:
#
#
# 1. Temperature (F) vs. Latitude
#
# 2. Humidity (%) vs. Latitude
#
# 3. Cloudiness (%) vs. Latitude
#
# 4. Wind Speed (mph) vs. Latitude

# %%
# List for holding lat_lngs and cities
# n = 500
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
cities
# Out:
# ['northam',
#  'albany',
#  'hobart',
#  'grand gaube',
#  'port augusta',
#  'ambilobe',
#  'sistranda',
#  'solovetskiy',
#  'bonga',
#  'clyde river',
#  'zwedru',
#  'ilulissat',
#  'sumbe',
#  'rikitea',
#  'bethel',
#  'azimur',
#  'huallanca',
#  'opatija',
#  'atuona',
#  'sumbawa',
#  'warqla',
#  'haibowan',
#  'tomatlan',
#  'aksu',
#  'dunhua',
#  'sola',
#  'chuy',
#  'tumannyy',
#  'port alfred',
#  'atambua',
#  'berdsk',
#  'ushuaia',
#  'puerto ayora',
#  'kodiak',
#  'sao filipe',
#  'arlit',
#  'barentsburg',
#  'mount gambier',
#  'severo-kurilsk',
#  'fortuna',
#  'kodinsk',
#  'polunochnoye',
#  'ribeira grande',
#  'alghero',
#  'nicolas bravo',
#  'olinda',
#  'ellensburg',
#  'oksfjord',
#  'pasni',
#  'tsihombe',
#  'lavrentiya',
#  'ponta do sol',
#  'shubarkuduk',
#  'butaritari',
#  'mataura',
#  'ponferrada',
#  'vila velha',
#  'khatanga',
#  'saint anthony',
#  'praya',
#  'edd',
#  'kahului',
#  'bonham',
#  'east london',
#  'henties bay',
#  'illoqqortoormiut',
#  'longyearbyen',
#  'arraial do cabo',
#  'barrow',
#  'ranghulu',
#  'omboue',
#  'hovd',
#  'busselton',
#  'komsomolskiy',
#  'nyrob',
#  'iqaluit',
#  'bawku',
#  'taolanaro',
#  'kapaa',
#  'isangel',
#  'castro',
#  'carnarvon',
#  'soyo',
#  'portland',
#  'kommunar',
#  'norman wells',
#  'grindavik',
#  'belushya guba',
#  'vardo',
#  'nizhneyansk',
#  'omaha',
#  'linchuan',
#  'kharan',
#  'esperance',
#  'acapulco',
#  'gat',
#  'emborion',
#  'guozhen',
#  'new norfolk',
#  'nabire',
#  'tahe',
#  'te anau',
#  'cayenne',
#  'avarua',
#  'vanavara',
#  'geraldton',
#  'chuncheng',
#  'tiksi',
#  'milingimbi',
#  'port hedland',
#  'porto novo',
#  'kupang',
#  'anderson',
#  'alofi',
#  'nikolskoye',
#  'samalaeulu',
#  'sao joao da barra',
#  'airai',
#  'hilo',
#  'victoria',
#  'nanpiao',
#  'sabang',
#  'lebu',
#  'pakenham',
#  'cape town',
#  'mys shmidta',
#  'zhanakorgan',
#  'husavik',
#  'hamilton',
#  'mahadday weyne',
#  'asau',
#  'phek',
#  'saint-augustin',
#  'bohodukhiv',
#  'kavaratti',
#  'la palma',
#  'lubartow',
#  'mogadishu',
#  'oktyabrskoye',
#  'umzimvubu',
#  'sitka',
#  'hermanus',
#  'pitangui',
#  'margate',
#  'padang',
#  'mar del plata',
#  'cap-aux-meules',
#  'yellowknife',
#  'paragominas',
#  'pangnirtung',
#  'vaini',
#  'chake chake',
#  'taksimo',
#  'hithadhoo',
#  'baoro',
#  'una',
#  'nanortalik',
#  'tuktoyaktuk',
#  'punta arenas',
#  'lekoni',
#  'jamestown',
#  'wanning',
#  'tasiilaq',
#  'taoudenni',
#  'denpasar',
#  'beringovskiy',
#  'dikson',
#  'yumen',
#  'huarmey',
#  'sataua',
#  'college',
#  'honningsvag',
#  'salinopolis',
#  'bataipora',
#  'coquimbo',
#  'kassala',
#  'saint george',
#  'san felipe',
#  'upernavik',
#  'mishan',
#  'bredasdorp',
#  'emba',
#  'robertson',
#  'vigia',
#  'prabumulih',
#  'warren',
#  'shirokiy',
#  'kalisz',
#  'mabaruma',
#  'mafeteng',
#  'cidreira',
#  'mezen',
#  'port hawkesbury',
#  'mitsamiouli',
#  'aflu',
#  'groton',
#  'bolshaya vishera',
#  'kaitangata',
#  'cockburn town',
#  'sangar',
#  'cabedelo',
#  'bonthe',
#  'talnakh',
#  'torbay',
#  'sin-le-noble',
#  'poum',
#  'altamira',
#  'leningradskiy',
#  'crab hill',
#  'lorengau',
#  'sorong',
#  'greenville',
#  'polyarnyy',
#  'byron bay',
#  'port elizabeth',
#  'hihifo',
#  'volot',
#  'lagoa',
#  'puerto madryn',
#  'tarauaca',
#  'valparaiso',
#  'thompson',
#  'baoning',
#  'asyut',
#  'glomfjord',
#  'bluff',
#  'kalanguy',
#  'catuday',
#  'pangkalanbuun',
#  'haines junction',
#  'camana',
#  'lata',
#  'sakakah',
#  'marsh harbour',
#  'yenagoa',
#  'nizhnyaya tavda',
#  'chimbote',
#  'qaanaaq',
#  'palmetto',
#  'ahuimanu',
#  'hofn',
#  'ancud',
#  'casablanca',
#  'wajima',
#  'huilong',
#  'umm lajj',
#  'raha',
#  'souillac',
#  'cabo san lucas',
#  'fairbanks',
#  'zapolyarnyy',
#  'bantogon',
#  'tuatapere',
#  'chara',
#  'richards bay',
#  'dingle',
#  'thongwa',
#  'grand river south east',
#  'gotsu',
#  'rosetown',
#  'kavieng',
#  'keshan',
#  'jabiru',
#  'holoby',
#  'zaria',
#  'bathsheba',
#  'mayo',
#  'nara',
#  'belmonte',
#  'lompoc',
#  'bengkulu',
#  'porto velho',
#  'jiddah',
#  'mahebourg',
#  'jaguey grande',
#  'pevek',
#  'murakami',
#  'aginskoye',
#  'hasaki',
#  'fiumicino',
#  'kruisfontein',
#  'vila franca do campo',
#  'westport',
#  'nanma',
#  'sao marcos',
#  'austell',
#  'pyatnitskoye',
#  'ha',
#  'cartagena del chaira',
#  'el tocuyo',
#  'temaraia',
#  'sentyabrskiy',
#  'katsuura',
#  'saskylakh',
#  'vaitape',
#  'basco',
#  'jiayuguan',
#  'half moon bay',
#  'palana',
#  'birjand',
#  'balkanabat',
#  'egvekinot',
#  'puerto del rosario',
#  'saint-pierre',
#  'vaitupu',
#  'dauriya',
#  'atar',
#  'lhokseumawe',
#  'bolobo',
#  'umm kaddadah',
#  'cap malheureux',
#  'dutse',
#  'bukama',
#  'kinablangan',
#  'barawe',
#  'finschhafen',
#  'helmbrechts',
#  'shingu',
#  'kalabo',
#  'georgetown',
#  'bonavista',
#  'bokoro',
#  'constitucion',
#  'timizart',
#  'nome',
#  'bermejo',
#  'garissa',
#  'russkiy',
#  'mushie',
#  'provideniya',
#  'zabol',
#  'tromso',
#  'linhares',
#  'piet retief',
#  'saint-philippe',
#  'tazovskiy',
#  'harsin',
#  'tabukiniberu',
#  'riyadh',
#  'samarai',
#  'surin',
#  'erdenet',
#  'buala',
#  'jasper',
#  'nichinan',
#  'attawapiskat',
#  'pacific grove',
#  'cheuskiny',
#  'monrovia',
#  'naze',
#  'port blair',
#  'talawdi',
#  'halalo',
#  'qarchak',
#  'oistins',
#  'port hardy',
#  'muros',
#  'khandyga',
#  'chipping sodbury',
#  'srednekolymsk',
#  'kluczbork',
#  'cherskiy',
#  'zomba',
#  'tessalit',
#  'aswan',
#  'qianan',
#  'yermolayevo',
#  'phalaborwa',
#  'bandarbeyla',
#  'kamenka',
#  'suruc',
#  'khormuj',
#  'ulaangom',
#  'fonte boa',
#  'xining',
#  'norsup',
#  'lev tolstoy',
#  'high rock',
#  'alugan',
#  'perth',
#  'nabulao',
#  'palmas',
#  'port lincoln',
#  'olafsvik',
#  'narsaq',
#  'hun',
#  'kasulu',
#  'labuhan',
#  'vostok',
#  'vresina',
#  'micheweni',
#  'bargal',
#  'tual',
#  'vao',
#  'krasnyy chikoy',
#  'dongying',
#  'port macquarie',
#  'honiara',
#  'shache',
#  'terme',
#  'tahta',
#  'kontagora',
#  'harper',
#  'kalianget',
#  'teguldet',
#  'tarudant',
#  'san antonio de los banos',
#  'chuari khas',
#  'alice springs',
#  'oussouye',
#  'bardiyah',
#  'posse',
#  'los andes',
#  'iquique',
#  'solsvik',
#  'shimoda',
#  'suvorovo',
#  'flin flon',
#  'bathurst',
#  'nuzvid',
#  'saurimo',
#  'ketchikan',
#  'tailai',
#  'karratha',
#  'tidore',
#  'roebourne',
#  'toliary',
#  'chapais',
#  'korcula',
#  'berdigestyakh',
#  'el estor',
#  'meulaboh',
#  'markala',
#  'laa',
#  'upata',
#  'puerto escondido',
#  'halifax',
#  'lingao',
#  'korla',
#  'llangefni',
#  'ust-maya',
#  'bambanglipuro',
#  'canon city',
#  'kalmunai',
#  'show low',
#  'ulagan',
#  'lakhimpur',
#  'vohibinany',
#  'zvishavane',
#  'mahaicony',
#  'amderma',
#  'rio branco',
#  'ahipara',
#  'nador',
#  'martapura',
#  'voh',
#  'los llanos de aridane',
#  'pankrushikha',
#  'caramay',
#  'bajil',
#  'waipawa',
#  'evanston',
#  'manta',
#  'pestovo',
#  'havoysund',
#  'san lawrenz',
#  'ajdabiya',
#  'khonuu',
#  'ayagoz',
#  'walvis bay',
#  'akyab',
#  'bontang',
#  'camocim',
#  'okhotsk',
#  'saldanha',
#  'puerto ayacucho',
#  'dinsor',
#  'lodeynoye pole',
#  'tikhmenevo',
#  'ostrovnoy',
#  'nguru',
#  'ixtapa',
#  'yialos',
#  'urengoy',
#  'nyurba',
#  'yatou',
#  'sao jose da coroa grande',
#  'caravelas',
#  'sofiyivka',
#  'port-gentil',
#  'havelock',
#  'batagay-alyta',
#  'khash',
#  'rongcheng',
#  'nuuk',
#  'tshikapa',
#  'hobe sound',
#  'samusu',
#  'chokurdakh',
#  'dekar',
#  'tagusao',
#  'adrar',
#  'skagen',
#  'indianola',
#  'kerouane',
#  'kheri',
#  'teneguiban',
#  'hervey bay',
#  'nemuro',
#  'espanola',
#  'nahrin',
#  'laguna',
#  'meyungs',
#  'kidero',
#  'nouadhibou',
#  'flinders',
#  'faya',
#  'derry',
#  'bulawayo',
#  'kyshtovka',
#  'yertsevo',
#  'ape',
#  'tiznit',
#  'eyl',
#  'lagos',
#  'shenjiamen',
#  'roald',
#  'izhma',
#  'abu dhabi',
#  'guerrero negro',
#  'kailua',
#  'santa ines',
#  'dapaong',
#  'tabiauea',
#  'la macarena',
#  'batemans bay',
#  'hami',
#  'saucillo',
#  'golden',
#  'senmonorom',
#  'washougal',
#  'yar-sale',
#  'comodoro rivadavia',
#  'yinchuan',
#  'avera',
#  'yarmouth',
#  'sainte-rose',
#  'atbasar',
#  'north myrtle beach',
#  'uige',
#  'mlonggo',
#  'kenai',
#  'sept-iles',
#  'matara',
#  'cabo rojo',
#  'thinadhoo',
#  'ulkan',
#  'la ronge',
#  'townsville',
#  'louisbourg',
#  'bend',
#  'sambava',
#  'luanda',
#  'astorga',
#  'birao',
#  'bozoum',
#  'rio grande',
#  'coari',
#  'mumbwa',
#  'fare',
#  'karasjok',
#  'pundaguitan',
#  'tubinskiy',
#  'umkomaas',
#  'puri',
#  'klaksvik',
#  'qaqortoq',
#  'abha',
#  'yaring',
#  'jardim',
#  'timmins',
#  'lianzhou',
#  'yongan',
#  'le vauclin',
#  'fort william',
#  'guano',
#  'luderitz',
#  'kloulklubed',
#  'liverpool',
#  'beyneu',
#  'tawkar',
#  'camacha',
#  'butte',
#  'do rud',
#  'alta floresta',
#  'pemba',
#  'bam',
#  'lasa',
#  'samana',
#  'prince rupert',
#  'jurm',
#  'sarrebourg',
#  'saint-joseph',
#  'nago',
#  'albacete',
#  'reserva',
#  'baculin',
#  'paamiut',
#  'beloha',
#  'albanel',
#  'anadyr',
#  'bristol',
#  'yeppoon',
#  'trelew',
#  'santa rosa',
#  'kieta',
#  'petaluma',
#  'kamen-rybolov',
#  'magdalena']

# %%
for each in enumerate(cities):
    print(each)
# Out:
# (0, 'northam')
# (1, 'albany')
# (2, 'hobart')
# (3, 'grand gaube')
# (4, 'port augusta')
# (5, 'ambilobe')
# (6, 'sistranda')
# (7, 'solovetskiy')
# (8, 'bonga')
# (9, 'clyde river')
# (10, 'zwedru')
# (11, 'ilulissat')
# (12, 'sumbe')
# (13, 'rikitea')
# (14, 'bethel')
# (15, 'azimur')
# (16, 'huallanca')
# (17, 'opatija')
# (18, 'atuona')
# (19, 'sumbawa')
# (20, 'warqla')
# (21, 'haibowan')
# (22, 'tomatlan')
# (23, 'aksu')
# (24, 'dunhua')
# (25, 'sola')
# (26, 'chuy')
# (27, 'tumannyy')
# (28, 'port alfred')
# (29, 'atambua')
# (30, 'berdsk')
# (31, 'ushuaia')
# (32, 'puerto ayora')
# (33, 'kodiak')
# (34, 'sao filipe')
# (35, 'arlit')
# (36, 'barentsburg')
# (37, 'mount gambier')
# (38, 'severo-kurilsk')
# (39, 'fortuna')
# (40, 'kodinsk')
# (41, 'polunochnoye')
# (42, 'ribeira grande')
# (43, 'alghero')
# (44, 'nicolas bravo')
# (45, 'olinda')
# (46, 'ellensburg')
# (47, 'oksfjord')
# (48, 'pasni')
# (49, 'tsihombe')
# (50, 'lavrentiya')
# (51, 'ponta do sol')
# (52, 'shubarkuduk')
# (53, 'butaritari')
# (54, 'mataura')
# (55, 'ponferrada')
# (56, 'vila velha')
# (57, 'khatanga')
# (58, 'saint anthony')
# (59, 'praya')
# (60, 'edd')
# (61, 'kahului')
# (62, 'bonham')
# (63, 'east london')
# (64, 'henties bay')
# (65, 'illoqqortoormiut')
# (66, 'longyearbyen')
# (67, 'arraial do cabo')
# (68, 'barrow')
# (69, 'ranghulu')
# (70, 'omboue')
# (71, 'hovd')
# (72, 'busselton')
# (73, 'komsomolskiy')
# (74, 'nyrob')
# (75, 'iqaluit')
# (76, 'bawku')
# (77, 'taolanaro')
# (78, 'kapaa')
# (79, 'isangel')
# (80, 'castro')
# (81, 'carnarvon')
# (82, 'soyo')
# (83, 'portland')
# (84, 'kommunar')
# (85, 'norman wells')
# (86, 'grindavik')
# (87, 'belushya guba')
# (88, 'vardo')
# (89, 'nizhneyansk')
# (90, 'omaha')
# (91, 'linchuan')
# (92, 'kharan')
# (93, 'esperance')
# (94, 'acapulco')
# (95, 'gat')
# (96, 'emborion')
# (97, 'guozhen')
# (98, 'new norfolk')
# (99, 'nabire')
# (100, 'tahe')
# (101, 'te anau')
# (102, 'cayenne')
# (103, 'avarua')
# (104, 'vanavara')
# (105, 'geraldton')
# (106, 'chuncheng')
# (107, 'tiksi')
# (108, 'milingimbi')
# (109, 'port hedland')
# (110, 'porto novo')
# (111, 'kupang')
# (112, 'anderson')
# (113, 'alofi')
# (114, 'nikolskoye')
# (115, 'samalaeulu')
# (116, 'sao joao da barra')
# (117, 'airai')
# (118, 'hilo')
# (119, 'victoria')
# (120, 'nanpiao')
# (121, 'sabang')
# (122, 'lebu')
# (123, 'pakenham')
# (124, 'cape town')
# (125, 'mys shmidta')
# (126, 'zhanakorgan')
# (127, 'husavik')
# (128, 'hamilton')
# (129, 'mahadday weyne')
# (130, 'asau')
# (131, 'phek')
# (132, 'saint-augustin')
# (133, 'bohodukhiv')
# (134, 'kavaratti')
# (135, 'la palma')
# (136, 'lubartow')
# (137, 'mogadishu')
# (138, 'oktyabrskoye')
# (139, 'umzimvubu')
# (140, 'sitka')
# (141, 'hermanus')
# (142, 'pitangui')
# (143, 'margate')
# (144, 'padang')
# (145, 'mar del plata')
# (146, 'cap-aux-meules')
# (147, 'yellowknife')
# (148, 'paragominas')
# (149, 'pangnirtung')
# (150, 'vaini')
# (151, 'chake chake')
# (152, 'taksimo')
# (153, 'hithadhoo')
# (154, 'baoro')
# (155, 'una')
# (156, 'nanortalik')
# (157, 'tuktoyaktuk')
# (158, 'punta arenas')
# (159, 'lekoni')
# (160, 'jamestown')
# (161, 'wanning')
# (162, 'tasiilaq')
# (163, 'taoudenni')
# (164, 'denpasar')
# (165, 'beringovskiy')
# (166, 'dikson')
# (167, 'yumen')
# (168, 'huarmey')
# (169, 'sataua')
# (170, 'college')
# (171, 'honningsvag')
# (172, 'salinopolis')
# (173, 'bataipora')
# (174, 'coquimbo')
# (175, 'kassala')
# (176, 'saint george')
# (177, 'san felipe')
# (178, 'upernavik')
# (179, 'mishan')
# (180, 'bredasdorp')
# (181, 'emba')
# (182, 'robertson')
# (183, 'vigia')
# (184, 'prabumulih')
# (185, 'warren')
# (186, 'shirokiy')
# (187, 'kalisz')
# (188, 'mabaruma')
# (189, 'mafeteng')
# (190, 'cidreira')
# (191, 'mezen')
# (192, 'port hawkesbury')
# (193, 'mitsamiouli')
# (194, 'aflu')
# (195, 'groton')
# (196, 'bolshaya vishera')
# (197, 'kaitangata')
# (198, 'cockburn town')
# (199, 'sangar')
# (200, 'cabedelo')
# (201, 'bonthe')
# (202, 'talnakh')
# (203, 'torbay')
# (204, 'sin-le-noble')
# (205, 'poum')
# (206, 'altamira')
# (207, 'leningradskiy')
# (208, 'crab hill')
# (209, 'lorengau')
# (210, 'sorong')
# (211, 'greenville')
# (212, 'polyarnyy')
# (213, 'byron bay')
# (214, 'port elizabeth')
# (215, 'hihifo')
# (216, 'volot')
# (217, 'lagoa')
# (218, 'puerto madryn')
# (219, 'tarauaca')
# (220, 'valparaiso')
# (221, 'thompson')
# (222, 'baoning')
# (223, 'asyut')
# (224, 'glomfjord')
# (225, 'bluff')
# (226, 'kalanguy')
# (227, 'catuday')
# (228, 'pangkalanbuun')
# (229, 'haines junction')
# (230, 'camana')
# (231, 'lata')
# (232, 'sakakah')
# (233, 'marsh harbour')
# (234, 'yenagoa')
# (235, 'nizhnyaya tavda')
# (236, 'chimbote')
# (237, 'qaanaaq')
# (238, 'palmetto')
# (239, 'ahuimanu')
# (240, 'hofn')
# (241, 'ancud')
# (242, 'casablanca')
# (243, 'wajima')
# (244, 'huilong')
# (245, 'umm lajj')
# (246, 'raha')
# (247, 'souillac')
# (248, 'cabo san lucas')
# (249, 'fairbanks')
# (250, 'zapolyarnyy')
# (251, 'bantogon')
# (252, 'tuatapere')
# (253, 'chara')
# (254, 'richards bay')
# (255, 'dingle')
# (256, 'thongwa')
# (257, 'grand river south east')
# (258, 'gotsu')
# (259, 'rosetown')
# (260, 'kavieng')
# (261, 'keshan')
# (262, 'jabiru')
# (263, 'holoby')
# (264, 'zaria')
# (265, 'bathsheba')
# (266, 'mayo')
# (267, 'nara')
# (268, 'belmonte')
# (269, 'lompoc')
# (270, 'bengkulu')
# (271, 'porto velho')
# (272, 'jiddah')
# (273, 'mahebourg')
# (274, 'jaguey grande')
# (275, 'pevek')
# (276, 'murakami')
# (277, 'aginskoye')
# (278, 'hasaki')
# (279, 'fiumicino')
# (280, 'kruisfontein')
# (281, 'vila franca do campo')
# (282, 'westport')
# (283, 'nanma')
# (284, 'sao marcos')
# (285, 'austell')
# (286, 'pyatnitskoye')
# (287, 'ha')
# (288, 'cartagena del chaira')
# (289, 'el tocuyo')
# (290, 'temaraia')
# (291, 'sentyabrskiy')
# (292, 'katsuura')
# (293, 'saskylakh')
# (294, 'vaitape')
# (295, 'basco')
# (296, 'jiayuguan')
# (297, 'half moon bay')
# (298, 'palana')
# (299, 'birjand')
# (300, 'balkanabat')
# (301, 'egvekinot')
# (302, 'puerto del rosario')
# (303, 'saint-pierre')
# (304, 'vaitupu')
# (305, 'dauriya')
# (306, 'atar')
# (307, 'lhokseumawe')
# (308, 'bolobo')
# (309, 'umm kaddadah')
# (310, 'cap malheureux')
# (311, 'dutse')
# (312, 'bukama')
# (313, 'kinablangan')
# (314, 'barawe')
# (315, 'finschhafen')
# (316, 'helmbrechts')
# (317, 'shingu')
# (318, 'kalabo')
# (319, 'georgetown')
# (320, 'bonavista')
# (321, 'bokoro')
# (322, 'constitucion')
# (323, 'timizart')
# (324, 'nome')
# (325, 'bermejo')
# (326, 'garissa')
# (327, 'russkiy')
# (328, 'mushie')
# (329, 'provideniya')
# (330, 'zabol')
# (331, 'tromso')
# (332, 'linhares')
# (333, 'piet retief')
# (334, 'saint-philippe')
# (335, 'tazovskiy')
# (336, 'harsin')
# (337, 'tabukiniberu')
# (338, 'riyadh')
# (339, 'samarai')
# (340, 'surin')
# (341, 'erdenet')
# (342, 'buala')
# (343, 'jasper')
# (344, 'nichinan')
# (345, 'attawapiskat')
# (346, 'pacific grove')
# (347, 'cheuskiny')
# (348, 'monrovia')
# (349, 'naze')
# (350, 'port blair')
# (351, 'talawdi')
# (352, 'halalo')
# (353, 'qarchak')
# (354, 'oistins')
# (355, 'port hardy')
# (356, 'muros')
# (357, 'khandyga')
# (358, 'chipping sodbury')
# (359, 'srednekolymsk')
# (360, 'kluczbork')
# (361, 'cherskiy')
# (362, 'zomba')
# (363, 'tessalit')
# (364, 'aswan')
# (365, 'qianan')
# (366, 'yermolayevo')
# (367, 'phalaborwa')
# (368, 'bandarbeyla')
# (369, 'kamenka')
# (370, 'suruc')
# (371, 'khormuj')
# (372, 'ulaangom')
# (373, 'fonte boa')
# (374, 'xining')
# (375, 'norsup')
# (376, 'lev tolstoy')
# (377, 'high rock')
# (378, 'alugan')
# (379, 'perth')
# (380, 'nabulao')
# (381, 'palmas')
# (382, 'port lincoln')
# (383, 'olafsvik')
# (384, 'narsaq')
# (385, 'hun')
# (386, 'kasulu')
# (387, 'labuhan')
# (388, 'vostok')
# (389, 'vresina')
# (390, 'micheweni')
# (391, 'bargal')
# (392, 'tual')
# (393, 'vao')
# (394, 'krasnyy chikoy')
# (395, 'dongying')
# (396, 'port macquarie')
# (397, 'honiara')
# (398, 'shache')
# (399, 'terme')
# (400, 'tahta')
# (401, 'kontagora')
# (402, 'harper')
# (403, 'kalianget')
# (404, 'teguldet')
# (405, 'tarudant')
# (406, 'san antonio de los banos')
# (407, 'chuari khas')
# (408, 'alice springs')
# (409, 'oussouye')
# (410, 'bardiyah')
# (411, 'posse')
# (412, 'los andes')
# (413, 'iquique')
# (414, 'solsvik')
# (415, 'shimoda')
# (416, 'suvorovo')
# (417, 'flin flon')
# (418, 'bathurst')
# (419, 'nuzvid')
# (420, 'saurimo')
# (421, 'ketchikan')
# (422, 'tailai')
# (423, 'karratha')
# (424, 'tidore')
# (425, 'roebourne')
# (426, 'toliary')
# (427, 'chapais')
# (428, 'korcula')
# (429, 'berdigestyakh')
# (430, 'el estor')
# (431, 'meulaboh')
# (432, 'markala')
# (433, 'laa')
# (434, 'upata')
# (435, 'puerto escondido')
# (436, 'halifax')
# (437, 'lingao')
# (438, 'korla')
# (439, 'llangefni')
# (440, 'ust-maya')
# (441, 'bambanglipuro')
# (442, 'canon city')
# (443, 'kalmunai')
# (444, 'show low')
# (445, 'ulagan')
# (446, 'lakhimpur')
# (447, 'vohibinany')
# (448, 'zvishavane')
# (449, 'mahaicony')
# (450, 'amderma')
# (451, 'rio branco')
# (452, 'ahipara')
# (453, 'nador')
# (454, 'martapura')
# (455, 'voh')
# (456, 'los llanos de aridane')
# (457, 'pankrushikha')
# (458, 'caramay')
# (459, 'bajil')
# (460, 'waipawa')
# (461, 'evanston')
# (462, 'manta')
# (463, 'pestovo')
# (464, 'havoysund')
# (465, 'san lawrenz')
# (466, 'ajdabiya')
# (467, 'khonuu')
# (468, 'ayagoz')
# (469, 'walvis bay')
# (470, 'akyab')
# (471, 'bontang')
# (472, 'camocim')
# (473, 'okhotsk')
# (474, 'saldanha')
# (475, 'puerto ayacucho')
# (476, 'dinsor')
# (477, 'lodeynoye pole')
# (478, 'tikhmenevo')
# (479, 'ostrovnoy')
# (480, 'nguru')
# (481, 'ixtapa')
# (482, 'yialos')
# (483, 'urengoy')
# (484, 'nyurba')
# (485, 'yatou')
# (486, 'sao jose da coroa grande')
# (487, 'caravelas')
# (488, 'sofiyivka')
# (489, 'port-gentil')
# (490, 'havelock')
# (491, 'batagay-alyta')
# (492, 'khash')
# (493, 'rongcheng')
# (494, 'nuuk')
# (495, 'tshikapa')
# (496, 'hobe sound')
# (497, 'samusu')
# (498, 'chokurdakh')
# (499, 'dekar')
# (500, 'tagusao')
# (501, 'adrar')
# (502, 'skagen')
# (503, 'indianola')
# (504, 'kerouane')
# (505, 'kheri')
# (506, 'teneguiban')
# (507, 'hervey bay')
# (508, 'nemuro')
# (509, 'espanola')
# (510, 'nahrin')
# (511, 'laguna')
# (512, 'meyungs')
# (513, 'kidero')
# (514, 'nouadhibou')
# (515, 'flinders')
# (516, 'faya')
# (517, 'derry')
# (518, 'bulawayo')
# (519, 'kyshtovka')
# (520, 'yertsevo')
# (521, 'ape')
# (522, 'tiznit')
# (523, 'eyl')
# (524, 'lagos')
# (525, 'shenjiamen')
# (526, 'roald')
# (527, 'izhma')
# (528, 'abu dhabi')
# (529, 'guerrero negro')
# (530, 'kailua')
# (531, 'santa ines')
# (532, 'dapaong')
# (533, 'tabiauea')
# (534, 'la macarena')
# (535, 'batemans bay')
# (536, 'hami')
# (537, 'saucillo')
# (538, 'golden')
# (539, 'senmonorom')
# (540, 'washougal')
# (541, 'yar-sale')
# (542, 'comodoro rivadavia')
# (543, 'yinchuan')
# (544, 'avera')
# (545, 'yarmouth')
# (546, 'sainte-rose')
# (547, 'atbasar')
# (548, 'north myrtle beach')
# (549, 'uige')
# (550, 'mlonggo')
# (551, 'kenai')
# (552, 'sept-iles')
# (553, 'matara')
# (554, 'cabo rojo')
# (555, 'thinadhoo')
# (556, 'ulkan')
# (557, 'la ronge')
# (558, 'townsville')
# (559, 'louisbourg')
# (560, 'bend')
# (561, 'sambava')
# (562, 'luanda')
# (563, 'astorga')
# (564, 'birao')
# (565, 'bozoum')
# (566, 'rio grande')
# (567, 'coari')
# (568, 'mumbwa')
# (569, 'fare')
# (570, 'karasjok')
# (571, 'pundaguitan')
# (572, 'tubinskiy')
# (573, 'umkomaas')
# (574, 'puri')
# (575, 'klaksvik')
# (576, 'qaqortoq')
# (577, 'abha')
# (578, 'yaring')
# (579, 'jardim')
# (580, 'timmins')
# (581, 'lianzhou')
# (582, 'yongan')
# (583, 'le vauclin')
# (584, 'fort william')
# (585, 'guano')
# (586, 'luderitz')
# (587, 'kloulklubed')
# (588, 'liverpool')
# (589, 'beyneu')
# (590, 'tawkar')
# (591, 'camacha')
# (592, 'butte')
# (593, 'do rud')
# (594, 'alta floresta')
# (595, 'pemba')
# (596, 'bam')
# (597, 'lasa')
# (598, 'samana')
# (599, 'prince rupert')
# (600, 'jurm')
# (601, 'sarrebourg')
# (602, 'saint-joseph')
# (603, 'nago')
# (604, 'albacete')
# (605, 'reserva')
# (606, 'baculin')
# (607, 'paamiut')
# (608, 'beloha')
# (609, 'albanel')
# (610, 'anadyr')
# (611, 'bristol')
# (612, 'yeppoon')
# (613, 'trelew')
# (614, 'santa rosa')
# (615, 'kieta')
# (616, 'petaluma')
# (617, 'kamen-rybolov')
# (618, 'magdalena')

# %% [markdown]
# cities

# %%
# Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
query_url = f"{url}appid={api_key}&units={units}&q="

# %%
query_url
units
# Out:
# 'metric'

# %%
lat = []
temp = []
humid = []
lngtude = []
wind = []
city = []
date = []
max.temp = []
cloudiness = []
dtype = []

print(f"Beginning Data Retrieval  ")
print("----------------------------")
# Loop through the list of cities and perform a request for data on each
#for city in cities:
for index, each in enumerate(cities):

    response = requests.get(query_url + each).json()
    try:
        lat.append(response['coord']['lat'])
        lngtude.append(response['coord']['lngtude'])
        temp.append(response['main']['temp'])
        humid.append(response['main']['humid'])
        wind.append(response['wind']['speed'])
        print(f"Processing Record {index} of Set 1 | {each}")
    
    
    
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")

print(f"The latitude information received is: {lat}")
print(f"The temperature information received is: {temp}")
print("----------------------------")
print("Data Retrieval Complete  ")
print("----------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record 0 of Set 1 | northam
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | hobart
# Processing Record 3 of Set 1 | grand gaube
# Processing Record 4 of Set 1 | port augusta
# Processing Record 5 of Set 1 | ambilobe
# Processing Record 6 of Set 1 | sistranda
# Missing field/result... skipping.
# Processing Record 8 of Set 1 | bonga
# Processing Record 9 of Set 1 | clyde river
# Processing Record 10 of Set 1 | zwedru
# Processing Record 11 of Set 1 | ilulissat
# Processing Record 12 of Set 1 | sumbe
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | bethel
# Missing field/result... skipping.
# Processing Record 16 of Set 1 | huallanca
# Processing Record 17 of Set 1 | opatija
# Processing Record 18 of Set 1 | atuona
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Processing Record 22 of Set 1 | tomatlan
# Processing Record 23 of Set 1 | aksu
# Processing Record 24 of Set 1 | dunhua
# Processing Record 25 of Set 1 | sola
# Processing Record 26 of Set 1 | chuy
# Missing field/result... skipping.
# Processing Record 28 of Set 1 | port alfred
# Processing Record 29 of Set 1 | atambua
# Processing Record 30 of Set 1 | berdsk
# Processing Record 31 of Set 1 | ushuaia
# Processing Record 32 of Set 1 | puerto ayora
# Processing Record 33 of Set 1 | kodiak
# Processing Record 34 of Set 1 | sao filipe
# Processing Record 35 of Set 1 | arlit
# Missing field/result... skipping.
# Processing Record 37 of Set 1 | mount gambier
# Processing Record 38 of Set 1 | severo-kurilsk
# Processing Record 39 of Set 1 | fortuna
# Processing Record 40 of Set 1 | kodinsk
# Processing Record 41 of Set 1 | polunochnoye
# Processing Record 42 of Set 1 | ribeira grande
# Processing Record 43 of Set 1 | alghero
# Processing Record 44 of Set 1 | nicolas bravo
# Processing Record 45 of Set 1 | olinda
# Processing Record 46 of Set 1 | ellensburg
# Processing Record 47 of Set 1 | oksfjord
# Processing Record 48 of Set 1 | pasni
# Missing field/result... skipping.
# Processing Record 50 of Set 1 | lavrentiya
# Processing Record 51 of Set 1 | ponta do sol
# Processing Record 52 of Set 1 | shubarkuduk
# Processing Record 53 of Set 1 | butaritari
# Processing Record 54 of Set 1 | mataura
# Processing Record 55 of Set 1 | ponferrada
# Processing Record 56 of Set 1 | vila velha
# Processing Record 57 of Set 1 | khatanga
# Processing Record 58 of Set 1 | saint anthony
# Processing Record 59 of Set 1 | praya
# Processing Record 60 of Set 1 | edd
# Processing Record 61 of Set 1 | kahului
# Processing Record 62 of Set 1 | bonham
# Processing Record 63 of Set 1 | east london
# Processing Record 64 of Set 1 | henties bay
# Missing field/result... skipping.
# Processing Record 66 of Set 1 | longyearbyen
# Processing Record 67 of Set 1 | arraial do cabo
# Processing Record 68 of Set 1 | barrow
# Processing Record 69 of Set 1 | ranghulu
# Processing Record 70 of Set 1 | omboue
# Processing Record 71 of Set 1 | hovd
# Processing Record 72 of Set 1 | busselton
# Processing Record 73 of Set 1 | komsomolskiy
# Processing Record 74 of Set 1 | nyrob
# Processing Record 75 of Set 1 | iqaluit
# Processing Record 76 of Set 1 | bawku
# Missing field/result... skipping.
# Processing Record 78 of Set 1 | kapaa
# Processing Record 79 of Set 1 | isangel
# Processing Record 80 of Set 1 | castro
# Processing Record 81 of Set 1 | carnarvon
# Processing Record 82 of Set 1 | soyo
# Processing Record 83 of Set 1 | portland
# Processing Record 84 of Set 1 | kommunar
# Processing Record 85 of Set 1 | norman wells
# Processing Record 86 of Set 1 | grindavik
# Missing field/result... skipping.
# Processing Record 88 of Set 1 | vardo
# Missing field/result... skipping.
# Processing Record 90 of Set 1 | omaha
# Missing field/result... skipping.
# Processing Record 92 of Set 1 | kharan
# Processing Record 93 of Set 1 | esperance
# Processing Record 94 of Set 1 | acapulco
# Processing Record 95 of Set 1 | gat
# Processing Record 96 of Set 1 | emborion
# Processing Record 97 of Set 1 | guozhen
# Processing Record 98 of Set 1 | new norfolk
# Processing Record 99 of Set 1 | nabire
# Processing Record 100 of Set 1 | tahe
# Processing Record 101 of Set 1 | te anau
# Processing Record 102 of Set 1 | cayenne
# Processing Record 103 of Set 1 | avarua
# Processing Record 104 of Set 1 | vanavara
# Processing Record 105 of Set 1 | geraldton
# Processing Record 106 of Set 1 | chuncheng
# Processing Record 107 of Set 1 | tiksi
# Missing field/result... skipping.
# Processing Record 109 of Set 1 | port hedland
# Processing Record 110 of Set 1 | porto novo
# Processing Record 111 of Set 1 | kupang
# Processing Record 112 of Set 1 | anderson
# Processing Record 113 of Set 1 | alofi
# Processing Record 114 of Set 1 | nikolskoye
# Missing field/result... skipping.
# Processing Record 116 of Set 1 | sao joao da barra
# Processing Record 117 of Set 1 | airai
# Processing Record 118 of Set 1 | hilo
# Processing Record 119 of Set 1 | victoria
# Processing Record 120 of Set 1 | nanpiao
# Processing Record 121 of Set 1 | sabang
# Processing Record 122 of Set 1 | lebu
# Processing Record 123 of Set 1 | pakenham
# Processing Record 124 of Set 1 | cape town
# Missing field/result... skipping.
# Processing Record 126 of Set 1 | zhanakorgan
# Processing Record 127 of Set 1 | husavik
# Processing Record 128 of Set 1 | hamilton
# Missing field/result... skipping.
# Missing field/result... skipping.
# Processing Record 131 of Set 1 | phek
# Processing Record 132 of Set 1 | saint-augustin
# Processing Record 133 of Set 1 | bohodukhiv
# Processing Record 134 of Set 1 | kavaratti
# Processing Record 135 of Set 1 | la palma
# Processing Record 136 of Set 1 | lubartow
# Processing Record 137 of Set 1 | mogadishu
# Processing Record 138 of Set 1 | oktyabrskoye
# Missing field/result... skipping.
# Processing Record 140 of Set 1 | sitka
# Processing Record 141 of Set 1 | hermanus
# Processing Record 142 of Set 1 | pitangui
# Processing Record 143 of Set 1 | margate
# Processing Record 144 of Set 1 | padang
# Processing Record 145 of Set 1 | mar del plata
# Processing Record 146 of Set 1 | cap-aux-meules
# Processing Record 147 of Set 1 | yellowknife
# Processing Record 148 of Set 1 | paragominas
# Processing Record 149 of Set 1 | pangnirtung
# Processing Record 150 of Set 1 | vaini
# Processing Record 151 of Set 1 | chake chake
# Processing Record 152 of Set 1 | taksimo
# Processing Record 153 of Set 1 | hithadhoo
# Processing Record 154 of Set 1 | baoro
# Processing Record 155 of Set 1 | una
# Processing Record 156 of Set 1 | nanortalik
# Processing Record 157 of Set 1 | tuktoyaktuk
# Processing Record 158 of Set 1 | punta arenas
# Processing Record 159 of Set 1 | lekoni
# Processing Record 160 of Set 1 | jamestown
# Processing Record 161 of Set 1 | wanning
# Processing Record 162 of Set 1 | tasiilaq
# Processing Record 163 of Set 1 | taoudenni
# Processing Record 164 of Set 1 | denpasar
# Processing Record 165 of Set 1 | beringovskiy
# Processing Record 166 of Set 1 | dikson
# Processing Record 167 of Set 1 | yumen
# Processing Record 168 of Set 1 | huarmey
# Missing field/result... skipping.
# Processing Record 170 of Set 1 | college
# Processing Record 171 of Set 1 | honningsvag
# Processing Record 172 of Set 1 | salinopolis
# Processing Record 173 of Set 1 | bataipora
# Processing Record 174 of Set 1 | coquimbo
# Processing Record 175 of Set 1 | kassala
# Processing Record 176 of Set 1 | saint george
# Processing Record 177 of Set 1 | san felipe
# Processing Record 178 of Set 1 | upernavik
# Processing Record 179 of Set 1 | mishan
# Processing Record 180 of Set 1 | bredasdorp
# Processing Record 181 of Set 1 | emba
# Processing Record 182 of Set 1 | robertson
# Processing Record 183 of Set 1 | vigia
# Processing Record 184 of Set 1 | prabumulih
# Processing Record 185 of Set 1 | warren
# Processing Record 186 of Set 1 | shirokiy
# Processing Record 187 of Set 1 | kalisz
# Processing Record 188 of Set 1 | mabaruma
# Processing Record 189 of Set 1 | mafeteng
# Processing Record 190 of Set 1 | cidreira
# Processing Record 191 of Set 1 | mezen
# Processing Record 192 of Set 1 | port hawkesbury
# Processing Record 193 of Set 1 | mitsamiouli
# Missing field/result... skipping.
# Processing Record 195 of Set 1 | groton
# Missing field/result... skipping.
# Processing Record 197 of Set 1 | kaitangata
# Processing Record 198 of Set 1 | cockburn town
# Processing Record 199 of Set 1 | sangar
# Processing Record 200 of Set 1 | cabedelo
# Processing Record 201 of Set 1 | bonthe
# Processing Record 202 of Set 1 | talnakh
# Processing Record 203 of Set 1 | torbay
# Processing Record 204 of Set 1 | sin-le-noble
# Processing Record 205 of Set 1 | poum
# Processing Record 206 of Set 1 | altamira
# Processing Record 207 of Set 1 | leningradskiy
# Missing field/result... skipping.
# Processing Record 209 of Set 1 | lorengau
# Processing Record 210 of Set 1 | sorong
# Processing Record 211 of Set 1 | greenville
# Processing Record 212 of Set 1 | polyarnyy
# Processing Record 213 of Set 1 | byron bay
# Processing Record 214 of Set 1 | port elizabeth
# Missing field/result... skipping.
# Processing Record 216 of Set 1 | volot
# Processing Record 217 of Set 1 | lagoa
# Processing Record 218 of Set 1 | puerto madryn
# Processing Record 219 of Set 1 | tarauaca
# Processing Record 220 of Set 1 | valparaiso
# Processing Record 221 of Set 1 | thompson
# Processing Record 222 of Set 1 | baoning
# Processing Record 223 of Set 1 | asyut
# Processing Record 224 of Set 1 | glomfjord
# Processing Record 225 of Set 1 | bluff
# Processing Record 226 of Set 1 | kalanguy
# Processing Record 227 of Set 1 | catuday
# Processing Record 228 of Set 1 | pangkalanbuun
# Processing Record 229 of Set 1 | haines junction
# Missing field/result... skipping.
# Processing Record 231 of Set 1 | lata
# Missing field/result... skipping.
# Processing Record 233 of Set 1 | marsh harbour
# Processing Record 234 of Set 1 | yenagoa
# Processing Record 235 of Set 1 | nizhnyaya tavda
# Processing Record 236 of Set 1 | chimbote
# Processing Record 237 of Set 1 | qaanaaq
# Processing Record 238 of Set 1 | palmetto
# Processing Record 239 of Set 1 | ahuimanu
# Processing Record 240 of Set 1 | hofn
# Processing Record 241 of Set 1 | ancud
# Processing Record 242 of Set 1 | casablanca
# Processing Record 243 of Set 1 | wajima
# Processing Record 244 of Set 1 | huilong
# Processing Record 245 of Set 1 | umm lajj
# Processing Record 246 of Set 1 | raha
# Processing Record 247 of Set 1 | souillac
# Processing Record 248 of Set 1 | cabo san lucas
# Processing Record 249 of Set 1 | fairbanks
# Processing Record 250 of Set 1 | zapolyarnyy
# Processing Record 251 of Set 1 | bantogon
# Processing Record 252 of Set 1 | tuatapere
# Processing Record 253 of Set 1 | chara
# Processing Record 254 of Set 1 | richards bay
# Processing Record 255 of Set 1 | dingle
# Processing Record 256 of Set 1 | thongwa
# Missing field/result... skipping.
# Processing Record 258 of Set 1 | gotsu
# Processing Record 259 of Set 1 | rosetown
# Processing Record 260 of Set 1 | kavieng
# Missing field/result... skipping.
# Missing field/result... skipping.
# Processing Record 263 of Set 1 | holoby
# Processing Record 264 of Set 1 | zaria
# Processing Record 265 of Set 1 | bathsheba
# Processing Record 266 of Set 1 | mayo
# Processing Record 267 of Set 1 | nara
# Processing Record 268 of Set 1 | belmonte
# Processing Record 269 of Set 1 | lompoc
# Missing field/result... skipping.
# Processing Record 271 of Set 1 | porto velho
# Missing field/result... skipping.
# Processing Record 273 of Set 1 | mahebourg
# Processing Record 274 of Set 1 | jaguey grande
# Processing Record 275 of Set 1 | pevek
# Processing Record 276 of Set 1 | murakami
# Processing Record 277 of Set 1 | aginskoye
# Processing Record 278 of Set 1 | hasaki
# Processing Record 279 of Set 1 | fiumicino
# Processing Record 280 of Set 1 | kruisfontein
# Processing Record 281 of Set 1 | vila franca do campo
# Processing Record 282 of Set 1 | westport
# Processing Record 283 of Set 1 | nanma
# Processing Record 284 of Set 1 | sao marcos
# Processing Record 285 of Set 1 | austell
# Processing Record 286 of Set 1 | pyatnitskoye
# Missing field/result... skipping.
# Processing Record 288 of Set 1 | cartagena del chaira
# Processing Record 289 of Set 1 | el tocuyo
# Missing field/result... skipping.
# Missing field/result... skipping.
# Processing Record 292 of Set 1 | katsuura
# Processing Record 293 of Set 1 | saskylakh
# Processing Record 294 of Set 1 | vaitape
# Processing Record 295 of Set 1 | basco
# Processing Record 296 of Set 1 | jiayuguan
# Processing Record 297 of Set 1 | half moon bay
# Processing Record 298 of Set 1 | palana
# Processing Record 299 of Set 1 | birjand
# Processing Record 300 of Set 1 | balkanabat
# Processing Record 301 of Set 1 | egvekinot
# Processing Record 302 of Set 1 | puerto del rosario
# Processing Record 303 of Set 1 | saint-pierre
# Missing field/result... skipping.
# Processing Record 305 of Set 1 | dauriya
# Processing Record 306 of Set 1 | atar
# Processing Record 307 of Set 1 | lhokseumawe
# Processing Record 308 of Set 1 | bolobo
# Processing Record 309 of Set 1 | umm kaddadah
# Processing Record 310 of Set 1 | cap malheureux
# Processing Record 311 of Set 1 | dutse
# Processing Record 312 of Set 1 | bukama
# Processing Record 313 of Set 1 | kinablangan
# Missing field/result... skipping.
# Processing Record 315 of Set 1 | finschhafen
# Processing Record 316 of Set 1 | helmbrechts
# Processing Record 317 of Set 1 | shingu
# Processing Record 318 of Set 1 | kalabo
# Processing Record 319 of Set 1 | georgetown
# Processing Record 320 of Set 1 | bonavista
# Missing field/result... skipping.
# Processing Record 322 of Set 1 | constitucion
# Processing Record 323 of Set 1 | timizart
# Processing Record 324 of Set 1 | nome
# Processing Record 325 of Set 1 | bermejo
# Processing Record 326 of Set 1 | garissa
# Processing Record 327 of Set 1 | russkiy
# Processing Record 328 of Set 1 | mushie
# Processing Record 329 of Set 1 | provideniya
# Processing Record 330 of Set 1 | zabol
# Processing Record 331 of Set 1 | tromso
# Processing Record 332 of Set 1 | linhares
# Processing Record 333 of Set 1 | piet retief
# Processing Record 334 of Set 1 | saint-philippe
# Processing Record 335 of Set 1 | tazovskiy
# Processing Record 336 of Set 1 | harsin
# Missing field/result... skipping.
# Processing Record 338 of Set 1 | riyadh
# Processing Record 339 of Set 1 | samarai
# Processing Record 340 of Set 1 | surin
# Processing Record 341 of Set 1 | erdenet
# Processing Record 342 of Set 1 | buala
# Processing Record 343 of Set 1 | jasper
# Processing Record 344 of Set 1 | nichinan
# Missing field/result... skipping.
# Processing Record 346 of Set 1 | pacific grove
# Missing field/result... skipping.
# Processing Record 348 of Set 1 | monrovia
# Processing Record 349 of Set 1 | naze
# Processing Record 350 of Set 1 | port blair
# Missing field/result... skipping.
# Missing field/result... skipping.
# Processing Record 353 of Set 1 | qarchak
# Processing Record 354 of Set 1 | oistins
# Processing Record 355 of Set 1 | port hardy
# Processing Record 356 of Set 1 | muros
# Processing Record 357 of Set 1 | khandyga
# Processing Record 358 of Set 1 | chipping sodbury
# Processing Record 359 of Set 1 | srednekolymsk
# Processing Record 360 of Set 1 | kluczbork
# Processing Record 361 of Set 1 | cherskiy
# Processing Record 362 of Set 1 | zomba
# Processing Record 363 of Set 1 | tessalit
# Processing Record 364 of Set 1 | aswan
# Processing Record 365 of Set 1 | qianan
# Processing Record 366 of Set 1 | yermolayevo
# Processing Record 367 of Set 1 | phalaborwa
# Processing Record 368 of Set 1 | bandarbeyla
# Processing Record 369 of Set 1 | kamenka
# Processing Record 370 of Set 1 | suruc
# Missing field/result... skipping.
# Processing Record 372 of Set 1 | ulaangom
# Processing Record 373 of Set 1 | fonte boa
# Processing Record 374 of Set 1 | xining
# Processing Record 375 of Set 1 | norsup
# Processing Record 376 of Set 1 | lev tolstoy
# Processing Record 377 of Set 1 | high rock
# Processing Record 378 of Set 1 | alugan
# Processing Record 379 of Set 1 | perth
# Processing Record 380 of Set 1 | nabulao
# Processing Record 381 of Set 1 | palmas
# Processing Record 382 of Set 1 | port lincoln
# Missing field/result... skipping.
# Processing Record 384 of Set 1 | narsaq
# Processing Record 385 of Set 1 | hun
# Processing Record 386 of Set 1 | kasulu
# Processing Record 387 of Set 1 | labuhan
# Processing Record 388 of Set 1 | vostok
# Processing Record 389 of Set 1 | vresina
# Processing Record 390 of Set 1 | micheweni
# Missing field/result... skipping.
# Processing Record 392 of Set 1 | tual
# Processing Record 393 of Set 1 | vao
# Processing Record 394 of Set 1 | krasnyy chikoy
# Processing Record 395 of Set 1 | dongying
# Processing Record 396 of Set 1 | port macquarie
# Processing Record 397 of Set 1 | honiara
# Processing Record 398 of Set 1 | shache
# Processing Record 399 of Set 1 | terme
# Missing field/result... skipping.
# Processing Record 401 of Set 1 | kontagora
# Processing Record 402 of Set 1 | harper
# Processing Record 403 of Set 1 | kalianget
# Processing Record 404 of Set 1 | teguldet
# Missing field/result... skipping.
# Processing Record 406 of Set 1 | san antonio de los banos
# Processing Record 407 of Set 1 | chuari khas
# Processing Record 408 of Set 1 | alice springs
# Processing Record 409 of Set 1 | oussouye
# Missing field/result... skipping.
# Processing Record 411 of Set 1 | posse
# Processing Record 412 of Set 1 | los andes
# Processing Record 413 of Set 1 | iquique
# Missing field/result... skipping.
# Processing Record 415 of Set 1 | shimoda
# Processing Record 416 of Set 1 | suvorovo
# Processing Record 417 of Set 1 | flin flon
# Processing Record 418 of Set 1 | bathurst
# Processing Record 419 of Set 1 | nuzvid
# Processing Record 420 of Set 1 | saurimo
# Processing Record 421 of Set 1 | ketchikan
# Processing Record 422 of Set 1 | tailai
# Processing Record 423 of Set 1 | karratha
# Missing field/result... skipping.
# Processing Record 425 of Set 1 | roebourne
# Missing field/result... skipping.
# Processing Record 427 of Set 1 | chapais
# Processing Record 428 of Set 1 | korcula
# Processing Record 429 of Set 1 | berdigestyakh
# Processing Record 430 of Set 1 | el estor
# Processing Record 431 of Set 1 | meulaboh
# Processing Record 432 of Set 1 | markala
# Processing Record 433 of Set 1 | laa
# Processing Record 434 of Set 1 | upata
# Processing Record 435 of Set 1 | puerto escondido
# Processing Record 436 of Set 1 | halifax
# Processing Record 437 of Set 1 | lingao
# Missing field/result... skipping.
# Processing Record 439 of Set 1 | llangefni
# Processing Record 440 of Set 1 | ust-maya
# Processing Record 441 of Set 1 | bambanglipuro
# Processing Record 442 of Set 1 | canon city
# Processing Record 443 of Set 1 | kalmunai
# Processing Record 444 of Set 1 | show low
# Processing Record 445 of Set 1 | ulagan
# Processing Record 446 of Set 1 | lakhimpur
# Processing Record 447 of Set 1 | vohibinany
# Processing Record 448 of Set 1 | zvishavane
# Missing field/result... skipping.
# Missing field/result... skipping.
# Processing Record 451 of Set 1 | rio branco
# Processing Record 452 of Set 1 | ahipara
# Processing Record 453 of Set 1 | nador
# Processing Record 454 of Set 1 | martapura
# Processing Record 455 of Set 1 | voh
# Processing Record 456 of Set 1 | los llanos de aridane
# Processing Record 457 of Set 1 | pankrushikha
# Processing Record 458 of Set 1 | caramay
# Processing Record 459 of Set 1 | bajil
# Processing Record 460 of Set 1 | waipawa
# Processing Record 461 of Set 1 | evanston
# Processing Record 462 of Set 1 | manta
# Processing Record 463 of Set 1 | pestovo
# Processing Record 464 of Set 1 | havoysund
# Processing Record 465 of Set 1 | san lawrenz
# Processing Record 466 of Set 1 | ajdabiya
# Missing field/result... skipping.
# Processing Record 468 of Set 1 | ayagoz
# Processing Record 469 of Set 1 | walvis bay
# Missing field/result... skipping.
# Processing Record 471 of Set 1 | bontang
# Processing Record 472 of Set 1 | camocim
# Processing Record 473 of Set 1 | okhotsk
# Processing Record 474 of Set 1 | saldanha
# Processing Record 475 of Set 1 | puerto ayacucho
# Missing field/result... skipping.
# Processing Record 477 of Set 1 | lodeynoye pole
# Missing field/result... skipping.
# Processing Record 479 of Set 1 | ostrovnoy
# Processing Record 480 of Set 1 | nguru
# Processing Record 481 of Set 1 | ixtapa
# Missing field/result... skipping.
# Processing Record 483 of Set 1 | urengoy
# Processing Record 484 of Set 1 | nyurba
# Processing Record 485 of Set 1 | yatou
# Processing Record 486 of Set 1 | sao jose da coroa grande
# Processing Record 487 of Set 1 | caravelas
# Processing Record 488 of Set 1 | sofiyivka
# Processing Record 489 of Set 1 | port-gentil
# Processing Record 490 of Set 1 | havelock
# Processing Record 491 of Set 1 | batagay-alyta
# Processing Record 492 of Set 1 | khash
# Processing Record 493 of Set 1 | rongcheng
# Processing Record 494 of Set 1 | nuuk
# Processing Record 495 of Set 1 | tshikapa
# Processing Record 496 of Set 1 | hobe sound
# Missing field/result... skipping.
# Processing Record 498 of Set 1 | chokurdakh
# Processing Record 499 of Set 1 | dekar
# Processing Record 500 of Set 1 | tagusao
# Processing Record 501 of Set 1 | adrar
# Processing Record 502 of Set 1 | skagen
# Processing Record 503 of Set 1 | indianola
# Processing Record 504 of Set 1 | kerouane
# Processing Record 505 of Set 1 | kheri
# Missing field/result... skipping.
# Processing Record 507 of Set 1 | hervey bay
# Processing Record 508 of Set 1 | nemuro
# Processing Record 509 of Set 1 | espanola
# Processing Record 510 of Set 1 | nahrin
# Processing Record 511 of Set 1 | laguna
# Missing field/result... skipping.
# Processing Record 513 of Set 1 | kidero
# Processing Record 514 of Set 1 | nouadhibou
# Processing Record 515 of Set 1 | flinders
# Processing Record 516 of Set 1 | faya
# Processing Record 517 of Set 1 | derry
# Processing Record 518 of Set 1 | bulawayo
# Processing Record 519 of Set 1 | kyshtovka
# Processing Record 520 of Set 1 | yertsevo
# Processing Record 521 of Set 1 | ape
# Processing Record 522 of Set 1 | tiznit
# Processing Record 523 of Set 1 | eyl
# Processing Record 524 of Set 1 | lagos
# Processing Record 525 of Set 1 | shenjiamen
# Processing Record 526 of Set 1 | roald
# Processing Record 527 of Set 1 | izhma
# Processing Record 528 of Set 1 | abu dhabi
# Processing Record 529 of Set 1 | guerrero negro
# Processing Record 530 of Set 1 | kailua
# Processing Record 531 of Set 1 | santa ines
# Processing Record 532 of Set 1 | dapaong
# Missing field/result... skipping.
# Processing Record 534 of Set 1 | la macarena
# Processing Record 535 of Set 1 | batemans bay
# Processing Record 536 of Set 1 | hami
# Processing Record 537 of Set 1 | saucillo
# Processing Record 538 of Set 1 | golden
# Missing field/result... skipping.
# Processing Record 540 of Set 1 | washougal
# Processing Record 541 of Set 1 | yar-sale
# Processing Record 542 of Set 1 | comodoro rivadavia
# Processing Record 543 of Set 1 | yinchuan
# Processing Record 544 of Set 1 | avera
# Processing Record 545 of Set 1 | yarmouth
# Processing Record 546 of Set 1 | sainte-rose
# Processing Record 547 of Set 1 | atbasar
# Processing Record 548 of Set 1 | north myrtle beach
# Processing Record 549 of Set 1 | uige
# Processing Record 550 of Set 1 | mlonggo
# Processing Record 551 of Set 1 | kenai
# Processing Record 552 of Set 1 | sept-iles
# Processing Record 553 of Set 1 | matara
# Processing Record 554 of Set 1 | cabo rojo
# Processing Record 555 of Set 1 | thinadhoo
# Processing Record 556 of Set 1 | ulkan
# Processing Record 557 of Set 1 | la ronge
# Processing Record 558 of Set 1 | townsville
# Missing field/result... skipping.
# Processing Record 560 of Set 1 | bend
# Processing Record 561 of Set 1 | sambava
# Processing Record 562 of Set 1 | luanda
# Processing Record 563 of Set 1 | astorga
# Processing Record 564 of Set 1 | birao
# Processing Record 565 of Set 1 | bozoum
# Processing Record 566 of Set 1 | rio grande
# Processing Record 567 of Set 1 | coari
# Processing Record 568 of Set 1 | mumbwa
# Processing Record 569 of Set 1 | fare
# Processing Record 570 of Set 1 | karasjok
# Processing Record 571 of Set 1 | pundaguitan
# Processing Record 572 of Set 1 | tubinskiy
# Processing Record 573 of Set 1 | umkomaas
# Processing Record 574 of Set 1 | puri
# Processing Record 575 of Set 1 | klaksvik
# Processing Record 576 of Set 1 | qaqortoq
# Processing Record 577 of Set 1 | abha
# Processing Record 578 of Set 1 | yaring
# Processing Record 579 of Set 1 | jardim
# Processing Record 580 of Set 1 | timmins
# Processing Record 581 of Set 1 | lianzhou
# Processing Record 582 of Set 1 | yongan
# Processing Record 583 of Set 1 | le vauclin
# Processing Record 584 of Set 1 | fort william
# Processing Record 585 of Set 1 | guano
# Processing Record 586 of Set 1 | luderitz
# Processing Record 587 of Set 1 | kloulklubed
# Processing Record 588 of Set 1 | liverpool
# Processing Record 589 of Set 1 | beyneu
# Missing field/result... skipping.
# Processing Record 591 of Set 1 | camacha
# Processing Record 592 of Set 1 | butte
# Missing field/result... skipping.
# Processing Record 594 of Set 1 | alta floresta
# Processing Record 595 of Set 1 | pemba
# Processing Record 596 of Set 1 | bam
# Processing Record 597 of Set 1 | lasa
# Processing Record 598 of Set 1 | samana
# Processing Record 599 of Set 1 | prince rupert
# Processing Record 600 of Set 1 | jurm
# Processing Record 601 of Set 1 | sarrebourg
# Processing Record 602 of Set 1 | saint-joseph
# Processing Record 603 of Set 1 | nago
# Processing Record 604 of Set 1 | albacete
# Processing Record 605 of Set 1 | reserva
# Processing Record 606 of Set 1 | baculin
# Processing Record 607 of Set 1 | paamiut
# Processing Record 608 of Set 1 | beloha
# Processing Record 609 of Set 1 | albanel
# Processing Record 610 of Set 1 | anadyr
# Processing Record 611 of Set 1 | bristol
# Processing Record 612 of Set 1 | yeppoon
# Processing Record 613 of Set 1 | trelew
# Processing Record 614 of Set 1 | santa rosa
# Processing Record 615 of Set 1 | kieta
# Processing Record 616 of Set 1 | petaluma
# Processing Record 617 of Set 1 | kamen-rybolov
# Processing Record 618 of Set 1 | magdalena
# The latitude information received is: [51.04, 42.65, -42.88, -20.01, -32.49, -13.19, 63.73, 7.26, 70.47, 6.07, 69.22, -11.2, -23.12, 60.79, -9.9, 45.33, -9.8, 19.93, 52.04, 43.37, 58.89, -33.69, -33.59, -9.11, 54.76, -54.81, -0.74, 39.95, 14.9, 18.74, -37.83, 50.68, 38.18, 58.6, 60.87, 38.52, 40.56, 24.39, -2.03, 47, 70.24, 25.26, 65.58, -20.63, 49.15, 3.07, -46.19, 42.55, -3.71, 71.98, 43.97, -8.71, 13.93, 20.89, 33.58, -33.02, -22.12, 78.22, -22.97, -38.31, 46.63, -1.57, 63.83, -33.64, 67.55, 60.74, 63.75, 11.06, 22.08, -19.55, -42.48, -30.97, -6.13, 45.52, 59.62, 65.28, 63.84, 39.62, 41.26, 28.58, 10.24, 16.86, 14.69, 40.48, 29.3, -42.78, -3.36, 52.34, -45.41, 4.94, -21.21, 60.35, 49.72, 22.17, 71.64, -20.31, -23.68, -10.16, 34.51, -19.06, 59.7, -21.64, -8.93, 19.71, 5.28, 41.1, 13.72, 8.96, -38.08, -33.93, 43.91, 50.56, 32.3, 25.7, 44.83, 50.16, 10.57, 5.36, 51.46, 2.04, 56.73, 37.17, -34.42, -19.68, -43.03, -0.92, -46.43, 47.38, 62.45, -3, 66.15, 15.34, -5.25, 56.36, -0.6, 5.69, -15.29, 60.14, 69.44, -53.16, -1.58, -33.21, 48.64, 65.61, 22.68, -8.65, 63.05, 73.51, 40.29, -10.07, 64.86, 70.98, -0.61, -22.3, -29.95, 15.45, 39.45, -32.75, 72.79, 45.55, -34.53, 34.81, -33.8, 40.51, -3.5, 42.48, 53.87, 51.76, 8.2, -29.82, -30.17, 65.85, 45.62, -11.38, 42.61, -46.28, 21.46, 63.92, -6.97, 7.53, 69.49, 47.66, 50.36, 41.28, -3.2, 69.38, -2.02, -0.86, 34.85, 69.2, -28.65, 39.31, 57.93, 37.14, -42.77, -8.16, 41.47, 55.74, 25.34, 27.18, 66.82, -23.58, 51.01, 16.29, -2.68, 60.75, 30.78, 26.54, 4.92, 57.67, -9.08, 77.48, 33.52, 21.44, 64.25, -41.87, 33.6, 37.4, 28.89, 25.02, 10.89, 45.6, 22.89, 64.84, 69.43, 6.53, -46.13, 39.42, -28.77, 11, 16.76, 35.01, 51.55, -2.57, 51.09, 11.11, 13.22, 63.59, 34.68, 40.36, 34.64, -8.75, -20.41, 22.53, 69.7, 38.29, 51.11, 35.73, 41.77, -34, 37.72, 53.8, 35.7, -28.97, 33.81, 54.34, 1.33, 9.79, 33.93, 71.97, -16.52, 40.33, 39.77, 37.46, 59.08, 32.86, 39.51, 66.32, 28.5, 48.95, 49.93, 20.52, 5.18, -2.17, 13.6, -19.98, 11.76, -9.2, 7.69, -6.6, 50.23, 33.72, -15, 6.8, 48.65, 23.99, 36.8, 30.04, -22.73, -0.46, 44.21, -3.02, 64.42, 31.03, 69.65, -19.38, -27.01, 45.36, 67.47, 34.27, 24.63, -10.62, 14.88, 49.03, -8.15, 33.83, 31.65, 36.62, 6.33, 5.43, 11.67, 35.44, 13.07, 50.7, 42.77, 62.65, 51.54, 67.46, 50.97, 68.75, -15.39, 20.2, 24.09, 44.99, 52.7, -23.95, 9.49, 53.19, 36.98, 49.98, -2.51, 36.62, -16.07, 53.21, 26.63, 12.22, 56.4, 9.66, -10.18, -34.72, 60.91, 50.34, -4.57, -2.54, 46.45, 49.82, -4.97, -5.67, 59.1, 50.36, 37.43, -31.43, -9.43, 38.42, 41.21, 10.4, 30.3, -7.35, 57.31, 22.89, 32.43, -23.7, 12.49, -14.08, -32.83, -20.22, 34.7, 43.33, 54.77, -33.42, 16.79, -9.66, 55.34, 46.39, -20.74, -20.77, 49.78, 42.96, 62.1, 15.53, 4.14, 13.69, 8.08, 8.02, 15.86, 44.65, 19.91, 53.26, 60.42, -7.95, 39.46, 7.42, 34.25, 50.63, 27.24, -17.35, -20.32, -9.98, -35.17, 35.17, -3.41, -20.95, 28.66, 53.83, 10.18, 38.23, -39.94, 42.04, 45.1, 55.36, 71, 36.06, 30.75, 47.96, -22.95, 0.12, -2.9, 59.36, 41.42, 5.66, 60.73, 68.05, 12.88, 20.71, 65.96, 63.29, 3.63, -8.9, -17.73, 48.05, -0.72, 34.88, 67.8, 28.22, 37.16, 64.17, -6.42, 27.06, 70.62, -21.53, 9.19, 27.87, 58.6, 40.24, 12.23, 21.85, -25.3, 43.32, 46.27, 36.06, 27.52, 42.19, 20.93, -34.58, 18.39, 42.88, -20.16, 56.56, 60.8, 57.54, 29.7, 7.98, 6.46, 29.96, 62.58, 65.01, 24.47, 27.97, 21.39, -0.82, 10.86, 2.18, -35.71, 42.84, 28.03, 51.3, 45.58, 66.83, -45.87, 38.48, 33.19, 50.71, 45.61, 51.81, 33.83, -7.61, -6.53, 60.55, 50.2, -13.74, 18.09, 0.53, 57.24, 55.1, -19.26, 44.06, -14.27, -8.83, 42.46, 10.3, 6.31, -32.03, -4.09, -14.99, -16.7, 69.47, 6.37, 52.89, -30.21, -7.54, 62.23, 60.72, 18.22, 6.87, -21.48, 48.48, 24.79, 39.7, 14.55, 56.82, -1.61, -26.65, 7.04, 53.41, 45.32, 33.08, 46.01, -9.87, -12.97, 29.11, 34.92, 0.12, 54.32, 36.86, 48.73, 43.56, 45.88, 39, -24.65, 7.45, 61.99, -25.17, 48.88, 64.73, 51.45, -23.13, -43.25, -36.62, -6.22, 38.23, 44.75, -13.26]
# The temperature information received is: [10.43, 24.9, 9, 23, 13, 23.58, 9, 16.28, -5, 21.38, -2, 22.23, 23.73, 8.3, 14.58, 18.01, 27.23, 32.28, 7, 4.88, 12.56, 16.28, 19.38, 21.58, 9, 3.72, 26, 21.7, 27.38, 29.13, 9.08, 8.23, 19, 4.53, -4.17, 18, 19, 24, 27, 12.15, 3.46, 27.73, 6.68, 23.28, 0.93, 28.78, 11.98, 6.38, 27, 0.43, 6.13, 25, 19.28, 29.21, 19.05, 22.48, 14.63, -5, 24, 14.88, -1.57, 25.93, 8.58, 18.73, -2.72, -1.22, -3, 26.88, 27.2, 23.73, 8.78, 16.78, 24.08, 16.54, 11, 1, 3.53, 26.71, 12.62, 9.13, 28, 30, 30, 8.43, 13.23, 9, 20.43, -3.62, 9.13, 29, 25, 1.28, 3, 20.38, -2.02, 23, 26, 22.83, 26.02, 27, 11, 25, 12.38, 23.77, 26.43, 1.23, 25.03, 13, 10, 16, 4.83, 4.58, 26, 16.23, 14.44, 11, 27.68, 21.98, 6.53, 25.53, 12.48, 8.43, 14.28, 28.58, 9, 26.18, 9.08, 11, 4, 25.18, -4, 21.58, 25.48, -3.27, 28.73, 22.08, 27.61, 1.23, -3, 5.61, 20.08, 11.73, 10, -1, 27.88, 19.23, 7.53, 3.73, -1.12, 20.78, 1.1, 6, 27.78, 30.98, 17, 19.23, 12, 19, -3.77, 2.38, 16, 20.63, 14.78, 15, 23.08, 28.43, 3.98, 9.03, 29.13, 16.78, 21.08, 5.43, 15, 24.98, 24.87, 14.13, 27.63, -3.32, 25, 25.83, 0.63, 6, 13.3, 6.58, 31, 2.38, 27.03, 26.88, 25.03, 5, 22, 25.72, 8.98, 20, 12.43, 31.23, 29.11, 0, 17, 24, 6.43, 21.03, -9.12, 24.63, 22.88, -0.92, 8.38, 27.73, 25.23, 1.88, 18.88, -8.97, 26.65, 28.43, 4.48, 9.63, 21, 18.43, 10.38, 27.43, 22.03, 17.56, 27.64, 1.1, 3, 21.73, 6.48, 12, 21.28, 24.08, 25, 18.33, 1.38, 27.18, 4.73, 22.68, 28, -4, 20.68, 9.08, 21.12, 32.78, 23, 31, -0.67, 18, -7.27, 16.32, 18, 16.83, 22, 13.88, -3.77, 18, 26.31, 3.03, 28.13, 29, 19.53, -0.07, 26.58, 27.78, -3.87, 24.01, 0.58, 5, 10.98, 2.63, 24.44, 14.33, -8.52, 29.63, 27.28, 23.48, 24.68, 23, 26.08, 23.98, 27.73, 21.78, 8, 22.88, 20.18, 30, 7.38, 24, 16.03, 28.34, 29.43, 24.98, 9.18, 24.08, 8, 15, 5, 26.28, 10.38, 26, 0.98, 16, 26, 25.93, 22.98, -5.22, 27.08, 28.56, 19.44, 20.07, 26, 24, 27.28, 17.5, 28, 11, 13, -9.67, 12.18, -4.77, 8.93, -6.27, 18.93, 22.48, 29, 4.28, 8.43, 20, 25.18, 4.88, 20, -7.67, 32.03, -9.37, 23.78, 4.68, 30, 24.83, 14, 26.63, 31, 13.28, -3, 13.83, 24, 20.98, -3.87, 10, 25.58, 26.98, 11.18, -7.52, 3.13, 17, 27, 4.08, 18, 21.33, 24.96, 18.48, 11.98, 29, 10.08, 15, 28, 31.18, 17.98, 19, 20.78, 11, 2, 10.63, 27.13, 18.38, 10.53, 0.78, 23.83, 23.83, 5, 15, -1.47, 30.28, 25.33, 25.33, 22.78, 32.48, 30, 16, 22.98, 15, -3.92, 20.13, 12.98, 23.08, 13.94, -7.87, 19.73, 20.23, 14.98, 33.83, 14.13, 19.87, 24.13, 22.98, 24, 8.28, 27.63, 11.83, 14.08, 27.63, 7.73, 5.66, 5.12, 21, 20.23, 1.93, 13, 25.78, 31.53, -0.87, 8.58, 25, 9.73, 2.63, 26.68, 30, 1.13, 2.78, 24, 24.63, 25.13, 9, 25.93, 27.89, -8.52, 5.78, 10.93, -1, 21.68, 29.25, -9.42, 17.43, 25.78, 29, 13, 4.69, 22.78, 18.93, 20.78, 14.53, 20.88, 4.08, 26, 3.93, 22, 13, 19, 25.02, 14.78, 5.38, 5.88, 10.53, 20.03, 25.08, 27, 20.08, 8.91, 2.08, 30, 23.83, 28.43, 18.61, 26.88, 28.63, 10.93, 3.43, 24.88, 9, 16.5, -0.22, 10, -4.37, 25.28, 9.69, 26, 2.58, 27.46, 18.53, 23.58, 10.6, 4, 18.38, 28, 27.53, -6.22, 2, 25, 13.77, 24.68, 25, 11, 23.98, 20.48, 21, 30.63, 18.53, 25.73, 3, 27.48, 7, 16.78, 18.98, 8, -3, 19, 23.58, 28.38, 5, 15.73, -7.27, 29, 12.73, 20, 14.28, 25, 10.39, 5.48, 20.57, 1.7, 29, 24, 10.73, 20.62, 32, 9, -5.77, 12.75, 17.7, 16.52, 13, 23.43, 25.23, 2.23, 22.08, 9, 7, 11.46, 22, 13.13, 18.38, 25.73, 24.78, 8.18, 34]
# ----------------------------
# Data Retrieval Complete
# ----------------------------

# %%
# Remove any cities that have NaN values
weather_df = weather_df.dropna(how='any')

print(f"The data frame contains {len(weather_df['City'])} unique cities.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-3ba51178ae9a> in <module>()
#       1
#       2 # Remove any cities that have NaN values
# ----> 3 weather_df = weather_df.dropna(how='any')
#       4
#       5 print(f"The data frame contains {len(weather_df['City'])} unique cities.")
#
# NameError: name 'weather_df' is not defined

# %%
# # Assemble everything into a data frame
# weather_df = pd.DataFrame({"City": cities,
#                            "Latitude": lats,
#                            "Longitude": lngs,
#                            #"
Humidity": humidity,
#                            #"Max Temp": temperature,
#                            #"Cloudiness": cloudiness,
#                            #"Wind Speed": wind_speed,
#                            #"Date": dates,
#                            #"Country": country_codes
#                           })
# weather_df
# Out:
#   File "<ipython-input-18-72329e58c23c>", line 6
#     Humidity": humidity,
#                         ^
# SyntaxError: EOL while scanning string literal

# %%
# Save Data to csv
cities_pd.to_csv("cities_Output.csv")

# Visualize to confirm airport data appears
cities_pd.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-022953b88da4> in <module>()
#       1 # Save Data to csv
# ----> 2 cities_pd.to_csv("cities_Output.csv")
#       3
#       4 # Visualize to confirm airport data appears
#       5 cities_pd.head(10)
#
# NameError: name 'cities_pd' is not defined

# %%
# create a data frame from cities, lat, and temp
weather_dict = {
    "city": cities,
    "lat": lat,
    "temp": temp
}
weather_data = pd.DataFrame(weather_dict)
weather_data.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-bddf218e34e8> in <module>()
#       5     "temp": temp
#       6 }
# ----> 7 weather_data = pd.DataFrame(weather_dict)
#       8 weather_data.head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     346                                  dtype=dtype, copy=copy)
#     347         elif isinstance(data, dict):
# --> 348             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     349         elif isinstance(data, ma.MaskedArray):
#     350             import numpy.ma.mrecords as mrecords
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _init_dict(self, data, index, columns, dtype)
#     457             arrays = [data[k] for k in keys]
#     458
# --> 459         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     460
#     461     def _init_ndarray(self, values, index, columns, dtype=None, copy=False):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    7313     # figure out the index, if necessary
#    7314     if index is None:
# -> 7315         index = extract_index(arrays)
#    7316
#    7317     # don't force copy because getting jammed in an ndarray anyway
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in extract_index(data)
#    7359             lengths = list(set(raw_lengths))
#    7360             if len(lengths) > 1:
# -> 7361                 raise ValueError('arrays must all be same length')
#    7362
#    7363             if have_dicts:
#
# ValueError: arrays must all be same length

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# #Create Scatter Plot, label and save it to a png in the Output folder, then display the plot
# plt.scatter(latitudelist, temperaturelist, marker="o", facecolors="red", edgecolors="black", alpha=0.75)
# plt.xlabel("Latitude (Degrees)")
# plt.ylabel("Temperature (Fahrenheit)")
# plt.title("City Latitude vs Average Temperature on 4/4/2018")
# plt.savefig("Output/Latitude_vs_Temperature")
# #plt.grid()
# plt.show()

# %%
# plt.scatter(urban_data, urban_avg_fare, s=urban_dr_count*.4, c="coral", alpha=.85,edgecolor="black",linewidths=1)
# plt.scatter(suburban_data, suburban_avg_fare, s=suburban_dr_count*.9, c="lightskyblue", alpha=1,edgecolor="black",linewidths=1)
# plt.scatter(rural_data, rural_avg_fare, s=rural_dr_count, c="gold", alpha=1,edgecolor="black",linewidths=1)
# plt.title("City Latitude vs. Max Temperature(10/06/2018)")
# plt.xlabel("Latitude")
# plt.ylabel("Max Temperature(F)")
# plt.legend(('Urban','Suburban','Rural'),loc = "upper right",title = "City Type",markerscale=.4)
# plt.text(45,35,"Notes:\nCircle size correlates with driver count per City")
# plt.grid(True)

# plt.show()

# %%
# plt.scatter("s=*.2, c="blue",edgecolor="black,linewidths=1)
# plt.title("City Latitude vs. Humiditym(10/06/2018)")
# plt.xlabel("Latitude")
# plt.ylabel("Humidity(%)")
# plt.grid(True)
# plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# plt.scatter("s=*.2, c="blue",edgecolor="black,linewidths=1)
# plt.title("City Latitude vs. Cloudiness(10/06/2018)")
# plt.xlabel("latitude")
# plt.ylabel("Cloudiness(%)")
# plt.grid(True)
# plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# plt.scatter("s=*.2, c="blue",edgecolor="black,linewidths=1)
# plt.title("City Latitude vs. wind Speed(10/06/2018)")
# plt.xlabel("Latitude")
# plt.ylabel("Wind Speed(mph)")
# plt.grid(True)
# plt.show()
